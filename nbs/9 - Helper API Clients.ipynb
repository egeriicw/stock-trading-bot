# %%
import setup
setup.init_django()

# %%
import helpers.clients as helper_clients

# %%
dataset_a = helper_clients.AlphaVantageAPIClient().get_stock_data()

# %%
dataset_b = helper_clients.PolygonAPIClient().get_stock_data()

# %%
dataset_a
# Out:
# [{'open_price': Decimal('184.5862'),
#   'close_price': Decimal('184.7753'),
#   'high_price': Decimal('184.8648'),
#   'low_price': Decimal('184.5763'),
#   'number_of_trades': None,
#   'volume': 7522,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5962'),
#   'close_price': Decimal('184.5962'),
#   'high_price': Decimal('184.6260'),
#   'low_price': Decimal('184.4966'),
#   'number_of_trades': None,
#   'volume': 3030,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6559'),
#   'close_price': Decimal('184.5962'),
#   'high_price': Decimal('184.6559'),
#   'low_price': Decimal('184.5962'),
#   'number_of_trades': None,
#   'volume': 3449,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5862'),
#   'close_price': Decimal('184.6559'),
#   'high_price': Decimal('184.6758'),
#   'low_price': Decimal('184.4966'),
#   'number_of_trades': None,
#   'volume': 1002,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6061'),
#   'close_price': Decimal('184.5464'),
#   'high_price': Decimal('184.6658'),
#   'low_price': Decimal('184.4469'),
#   'number_of_trades': None,
#   'volume': 4995,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4961'),
#   'close_price': Decimal('184.6758'),
#   'high_price': Decimal('184.6758'),
#   'low_price': Decimal('184.3971'),
#   'number_of_trades': None,
#   'volume': 3732,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.3474'),
#   'close_price': Decimal('184.4469'),
#   'high_price': Decimal('184.5464'),
#   'low_price': Decimal('184.3474'),
#   'number_of_trades': None,
#   'volume': 2533,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4369'),
#   'close_price': Decimal('184.5365'),
#   'high_price': Decimal('184.5464'),
#   'low_price': Decimal('184.3474'),
#   'number_of_trades': None,
#   'volume': 1547,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4966'),
#   'close_price': Decimal('184.3573'),
#   'high_price': Decimal('184.5365'),
#   'low_price': Decimal('184.2280'),
#   'number_of_trades': None,
#   'volume': 3927,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5066'),
#   'close_price': Decimal('184.5365'),
#   'high_price': Decimal('184.5464'),
#   'low_price': Decimal('184.4867'),
#   'number_of_trades': None,
#   'volume': 2457,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4668'),
#   'close_price': Decimal('184.4867'),
#   'high_price': Decimal('184.5265'),
#   'low_price': Decimal('184.4369'),
#   'number_of_trades': None,
#   'volume': 2776,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4767'),
#   'close_price': Decimal('184.4966'),
#   'high_price': Decimal('184.5265'),
#   'low_price': Decimal('184.3175'),
#   'number_of_trades': None,
#   'volume': 2810,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5265'),
#   'close_price': Decimal('184.4767'),
#   'high_price': Decimal('184.5365'),
#   'low_price': Decimal('184.2280'),
#   'number_of_trades': None,
#   'volume': 5184,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4170'),
#   'close_price': Decimal('184.4071'),
#   'high_price': Decimal('184.5464'),
#   'low_price': Decimal('184.4071'),
#   'number_of_trades': None,
#   'volume': 5433,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.3772'),
#   'close_price': Decimal('184.4071'),
#   'high_price': Decimal('184.4767'),
#   'low_price': Decimal('184.2479'),
#   'number_of_trades': None,
#   'volume': 5408,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.3971'),
#   'close_price': Decimal('184.3623'),
#   'high_price': Decimal('184.4170'),
#   'low_price': Decimal('184.1384'),
#   'number_of_trades': None,
#   'volume': 1466,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4469'),
#   'close_price': Decimal('184.4021'),
#   'high_price': Decimal('184.4767'),
#   'low_price': Decimal('184.3872'),
#   'number_of_trades': None,
#   'volume': 767,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.3474'),
#   'close_price': Decimal('184.4767'),
#   'high_price': Decimal('184.4966'),
#   'low_price': Decimal('184.3125'),
#   'number_of_trades': None,
#   'volume': 2910,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.2578'),
#   'close_price': Decimal('184.3772'),
#   'high_price': Decimal('184.3872'),
#   'low_price': Decimal('184.1583'),
#   'number_of_trades': None,
#   'volume': 2678,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.2777'),
#   'close_price': Decimal('184.2081'),
#   'high_price': Decimal('184.2777'),
#   'low_price': Decimal('183.5015'),
#   'number_of_trades': None,
#   'volume': 1777,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.0886'),
#   'close_price': Decimal('184.2727'),
#   'high_price': Decimal('184.2976'),
#   'low_price': Decimal('183.5015'),
#   'number_of_trades': None,
#   'volume': 4971,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.1583'),
#   'close_price': Decimal('184.0837'),
#   'high_price': Decimal('184.1782'),
#   'low_price': Decimal('183.9593'),
#   'number_of_trades': None,
#   'volume': 2953,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.2479'),
#   'close_price': Decimal('184.1782'),
#   'high_price': Decimal('184.3374'),
#   'low_price': Decimal('184.0986'),
#   'number_of_trades': None,
#   'volume': 1230,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.2180'),
#   'close_price': Decimal('184.2926'),
#   'high_price': Decimal('184.4568'),
#   'low_price': Decimal('184.1981'),
#   'number_of_trades': None,
#   'volume': 3778,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 23, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.2714'),
#   'close_price': Decimal('184.1981'),
#   'high_price': Decimal('184.2976'),
#   'low_price': Decimal('184.1085'),
#   'number_of_trades': None,
#   'volume': 547,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 22, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.0488'),
#   'close_price': Decimal('184.2180'),
#   'high_price': Decimal('184.3374'),
#   'low_price': Decimal('183.9493'),
#   'number_of_trades': None,
#   'volume': 2726,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 22, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.3175'),
#   'close_price': Decimal('184.0638'),
#   'high_price': Decimal('184.3872'),
#   'low_price': Decimal('183.8996'),
#   'number_of_trades': None,
#   'volume': 5466,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 22, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.2976'),
#   'close_price': Decimal('184.3175'),
#   'high_price': Decimal('184.3872'),
#   'low_price': Decimal('184.2777'),
#   'number_of_trades': None,
#   'volume': 3232,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 22, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.2280'),
#   'close_price': Decimal('184.2976'),
#   'high_price': Decimal('184.2976'),
#   'low_price': Decimal('184.1384'),
#   'number_of_trades': None,
#   'volume': 3787,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 22, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.2479'),
#   'close_price': Decimal('184.2976'),
#   'high_price': Decimal('184.2976'),
#   'low_price': Decimal('184.1185'),
#   'number_of_trades': None,
#   'volume': 2000,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 22, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.0986'),
#   'close_price': Decimal('184.2976'),
#   'high_price': Decimal('184.3573'),
#   'low_price': Decimal('184.0986'),
#   'number_of_trades': None,
#   'volume': 10881,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 22, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.1185'),
#   'close_price': Decimal('184.1284'),
#   'high_price': Decimal('184.1981'),
#   'low_price': Decimal('183.9692'),
#   'number_of_trades': None,
#   'volume': 3146,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 22, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.0986'),
#   'close_price': Decimal('184.0439'),
#   'high_price': Decimal('184.1384'),
#   'low_price': Decimal('183.9095'),
#   'number_of_trades': None,
#   'volume': 2103,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 22, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('183.9991'),
#   'close_price': Decimal('184.1085'),
#   'high_price': Decimal('184.1384'),
#   'low_price': Decimal('183.8996'),
#   'number_of_trades': None,
#   'volume': 11289,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 22, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.0289'),
#   'close_price': Decimal('183.9097'),
#   'high_price': Decimal('184.1384'),
#   'low_price': Decimal('183.8996'),
#   'number_of_trades': None,
#   'volume': 10651,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 22, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('183.9692'),
#   'close_price': Decimal('184.0488'),
#   'high_price': Decimal('184.1384'),
#   'low_price': Decimal('183.5015'),
#   'number_of_trades': None,
#   'volume': 202844,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 22, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('183.8498'),
#   'close_price': Decimal('183.9991'),
#   'high_price': Decimal('184.1384'),
#   'low_price': Decimal('183.6010'),
#   'number_of_trades': None,
#   'volume': 39932,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 21, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('183.8996'),
#   'close_price': Decimal('183.8598'),
#   'high_price': Decimal('186.9142'),
#   'low_price': Decimal('174.9000'),
#   'number_of_trades': None,
#   'volume': 24601,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 21, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.1384'),
#   'close_price': Decimal('183.8996'),
#   'high_price': Decimal('184.2976'),
#   'low_price': Decimal('183.7204'),
#   'number_of_trades': None,
#   'volume': 46165,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 21, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6957'),
#   'close_price': Decimal('184.1085'),
#   'high_price': Decimal('184.7454'),
#   'low_price': Decimal('183.5015'),
#   'number_of_trades': None,
#   'volume': 151294,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 21, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6260'),
#   'close_price': Decimal('184.7355'),
#   'high_price': Decimal('184.7852'),
#   'low_price': Decimal('184.5365'),
#   'number_of_trades': None,
#   'volume': 32125,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 21, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6857'),
#   'close_price': Decimal('184.6210'),
#   'high_price': Decimal('184.7952'),
#   'low_price': Decimal('184.6161'),
#   'number_of_trades': None,
#   'volume': 11373,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 21, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8449'),
#   'close_price': Decimal('184.6658'),
#   'high_price': Decimal('184.9146'),
#   'low_price': Decimal('184.6260'),
#   'number_of_trades': None,
#   'volume': 12453,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 21, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6977'),
#   'close_price': Decimal('184.8648'),
#   'high_price': Decimal('184.9445'),
#   'low_price': Decimal('183.5015'),
#   'number_of_trades': None,
#   'volume': 39852,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 21, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.9245'),
#   'close_price': Decimal('184.7056'),
#   'high_price': Decimal('185.0241'),
#   'low_price': Decimal('183.5015'),
#   'number_of_trades': None,
#   'volume': 33294,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 21, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.9445'),
#   'close_price': Decimal('184.9843'),
#   'high_price': Decimal('185.4868'),
#   'low_price': Decimal('183.5015'),
#   'number_of_trades': None,
#   'volume': 266437,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 21, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5962'),
#   'close_price': Decimal('184.9445'),
#   'high_price': Decimal('184.9942'),
#   'low_price': Decimal('183.5015'),
#   'number_of_trades': None,
#   'volume': 358768,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 21, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('183.5413'),
#   'close_price': Decimal('184.6310'),
#   'high_price': Decimal('184.7902'),
#   'low_price': Decimal('182.9243'),
#   'number_of_trades': None,
#   'volume': 20759032,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 21, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.1235'),
#   'close_price': Decimal('183.4617'),
#   'high_price': Decimal('184.3573'),
#   'low_price': Decimal('183.4518'),
#   'number_of_trades': None,
#   'volume': 2580990,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 20, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.2976'),
#   'close_price': Decimal('184.1235'),
#   'high_price': Decimal('184.3573'),
#   'low_price': Decimal('183.8399'),
#   'number_of_trades': None,
#   'volume': 1644498,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 20, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.2081'),
#   'close_price': Decimal('184.2877'),
#   'high_price': Decimal('184.4170'),
#   'low_price': Decimal('184.2081'),
#   'number_of_trades': None,
#   'volume': 641584,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 20, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4121'),
#   'close_price': Decimal('184.2130'),
#   'high_price': Decimal('184.5066'),
#   'low_price': Decimal('184.2031'),
#   'number_of_trades': None,
#   'volume': 442668,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 20, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.2081'),
#   'close_price': Decimal('184.4170'),
#   'high_price': Decimal('184.4468'),
#   'low_price': Decimal('184.1085'),
#   'number_of_trades': None,
#   'volume': 550001,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 20, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6161'),
#   'close_price': Decimal('184.2163'),
#   'high_price': Decimal('184.6844'),
#   'low_price': Decimal('184.1185'),
#   'number_of_trades': None,
#   'volume': 569090,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 20, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4071'),
#   'close_price': Decimal('184.6161'),
#   'high_price': Decimal('184.7454'),
#   'low_price': Decimal('184.2976'),
#   'number_of_trades': None,
#   'volume': 441264,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 20, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.1882'),
#   'close_price': Decimal('184.4120'),
#   'high_price': Decimal('184.6260'),
#   'low_price': Decimal('184.1334'),
#   'number_of_trades': None,
#   'volume': 566243,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 20, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.5962'),
#   'close_price': Decimal('184.1583'),
#   'high_price': Decimal('184.6857'),
#   'low_price': Decimal('184.1583'),
#   'number_of_trades': None,
#   'volume': 494851,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 20, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6161'),
#   'close_price': Decimal('184.6011'),
#   'high_price': Decimal('184.8151'),
#   'low_price': Decimal('184.3673'),
#   'number_of_trades': None,
#   'volume': 445556,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 20, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4170'),
#   'close_price': Decimal('184.6210'),
#   'high_price': Decimal('184.7056'),
#   'low_price': Decimal('184.1683'),
#   'number_of_trades': None,
#   'volume': 732235,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 20, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.0738'),
#   'close_price': Decimal('184.4146'),
#   'high_price': Decimal('185.1236'),
#   'low_price': Decimal('184.2479'),
#   'number_of_trades': None,
#   'volume': 771096,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 20, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.2231'),
#   'close_price': Decimal('185.0639'),
#   'high_price': Decimal('185.3950'),
#   'low_price': Decimal('185.0042'),
#   'number_of_trades': None,
#   'volume': 415135,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 19, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.5624'),
#   'close_price': Decimal('185.2231'),
#   'high_price': Decimal('185.6311'),
#   'low_price': Decimal('185.0241'),
#   'number_of_trades': None,
#   'volume': 458345,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 19, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.7654'),
#   'close_price': Decimal('185.5614'),
#   'high_price': Decimal('186.0291'),
#   'low_price': Decimal('185.5316'),
#   'number_of_trades': None,
#   'volume': 571896,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 19, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.5216'),
#   'close_price': Decimal('185.7536'),
#   'high_price': Decimal('185.8799'),
#   'low_price': Decimal('185.4221'),
#   'number_of_trades': None,
#   'volume': 664308,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 19, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.9693'),
#   'close_price': Decimal('185.4954'),
#   'high_price': Decimal('185.6112'),
#   'low_price': Decimal('184.5564'),
#   'number_of_trades': None,
#   'volume': 717550,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 19, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7653'),
#   'close_price': Decimal('184.9644'),
#   'high_price': Decimal('185.0838'),
#   'low_price': Decimal('184.6360'),
#   'number_of_trades': None,
#   'volume': 429403,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 19, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6459'),
#   'close_price': Decimal('184.7653'),
#   'high_price': Decimal('184.8449'),
#   'low_price': Decimal('184.6061'),
#   'number_of_trades': None,
#   'volume': 268251,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 19, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6708'),
#   'close_price': Decimal('184.6509'),
#   'high_price': Decimal('184.7156'),
#   'low_price': Decimal('184.5428'),
#   'number_of_trades': None,
#   'volume': 394210,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 19, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.9743'),
#   'close_price': Decimal('184.6559'),
#   'high_price': Decimal('184.9793'),
#   'low_price': Decimal('184.6061'),
#   'number_of_trades': None,
#   'volume': 393155,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 19, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8847'),
#   'close_price': Decimal('184.9743'),
#   'high_price': Decimal('185.0838'),
#   'low_price': Decimal('184.7494'),
#   'number_of_trades': None,
#   'volume': 449377,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 19, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6957'),
#   'close_price': Decimal('184.8549'),
#   'high_price': Decimal('185.0241'),
#   'low_price': Decimal('184.6857'),
#   'number_of_trades': None,
#   'volume': 401442,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 19, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.2629'),
#   'close_price': Decimal('184.7056'),
#   'high_price': Decimal('185.4122'),
#   'low_price': Decimal('184.3573'),
#   'number_of_trades': None,
#   'volume': 759187,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 19, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.4719'),
#   'close_price': Decimal('185.2728'),
#   'high_price': Decimal('185.4719'),
#   'low_price': Decimal('185.1932'),
#   'number_of_trades': None,
#   'volume': 314801,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 18, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.6211'),
#   'close_price': Decimal('185.4719'),
#   'high_price': Decimal('185.6211'),
#   'low_price': Decimal('185.4569'),
#   'number_of_trades': None,
#   'volume': 270044,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 18, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.4321'),
#   'close_price': Decimal('185.6112'),
#   'high_price': Decimal('185.6112'),
#   'low_price': Decimal('185.4023'),
#   'number_of_trades': None,
#   'volume': 325407,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 18, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.2927'),
#   'close_price': Decimal('185.4122'),
#   'high_price': Decimal('185.4221'),
#   'low_price': Decimal('185.2628'),
#   'number_of_trades': None,
#   'volume': 294038,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 18, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.3624'),
#   'close_price': Decimal('185.2927'),
#   'high_price': Decimal('185.4420'),
#   'low_price': Decimal('185.2828'),
#   'number_of_trades': None,
#   'volume': 230782,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 18, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.2629'),
#   'close_price': Decimal('185.3624'),
#   'high_price': Decimal('185.4520'),
#   'low_price': Decimal('185.2462'),
#   'number_of_trades': None,
#   'volume': 282354,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 18, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.1883'),
#   'close_price': Decimal('185.2529'),
#   'high_price': Decimal('185.2629'),
#   'low_price': Decimal('185.1813'),
#   'number_of_trades': None,
#   'volume': 168237,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 18, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.4122'),
#   'close_price': Decimal('185.1833'),
#   'high_price': Decimal('185.4420'),
#   'low_price': Decimal('185.1684'),
#   'number_of_trades': None,
#   'volume': 290350,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 18, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.2878'),
#   'close_price': Decimal('185.4022'),
#   'high_price': Decimal('185.4321'),
#   'low_price': Decimal('185.2728'),
#   'number_of_trades': None,
#   'volume': 293813,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 18, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.3425'),
#   'close_price': Decimal('185.2828'),
#   'high_price': Decimal('185.3724'),
#   'low_price': Decimal('185.2330'),
#   'number_of_trades': None,
#   'volume': 281252,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 18, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.4640'),
#   'close_price': Decimal('185.3525'),
#   'high_price': Decimal('185.5266'),
#   'low_price': Decimal('185.3223'),
#   'number_of_trades': None,
#   'volume': 240312,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 18, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.4221'),
#   'close_price': Decimal('185.4718'),
#   'high_price': Decimal('185.5316'),
#   'low_price': Decimal('185.4171'),
#   'number_of_trades': None,
#   'volume': 267931,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 18, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.3664'),
#   'close_price': Decimal('185.4171'),
#   'high_price': Decimal('185.4321'),
#   'low_price': Decimal('185.2480'),
#   'number_of_trades': None,
#   'volume': 271164,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 17, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.1236'),
#   'close_price': Decimal('185.3654'),
#   'high_price': Decimal('185.4022'),
#   'low_price': Decimal('185.1236'),
#   'number_of_trades': None,
#   'volume': 308564,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 17, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.1286'),
#   'close_price': Decimal('185.1236'),
#   'high_price': Decimal('185.1932'),
#   'low_price': Decimal('185.0042'),
#   'number_of_trades': None,
#   'volume': 306057,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 17, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.9942'),
#   'close_price': Decimal('185.1318'),
#   'high_price': Decimal('185.2032'),
#   'low_price': Decimal('184.9644'),
#   'number_of_trades': None,
#   'volume': 247575,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 17, 40, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.1769'),
#   'close_price': Decimal('185.0042'),
#   'high_price': Decimal('185.2728'),
#   'low_price': Decimal('184.9278'),
#   'number_of_trades': None,
#   'volume': 328462,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 17, 35, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.1733'),
#   'close_price': Decimal('185.1783'),
#   'high_price': Decimal('185.2430'),
#   'low_price': Decimal('185.0838'),
#   'number_of_trades': None,
#   'volume': 293372,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 17, 30, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.0191'),
#   'close_price': Decimal('185.1833'),
#   'high_price': Decimal('185.2032'),
#   'low_price': Decimal('185.0056'),
#   'number_of_trades': None,
#   'volume': 280847,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 17, 25, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.9955'),
#   'close_price': Decimal('185.0141'),
#   'high_price': Decimal('186.0888'),
#   'low_price': Decimal('184.9395'),
#   'number_of_trades': None,
#   'volume': 252148,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 17, 20, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.0589'),
#   'close_price': Decimal('184.9992'),
#   'high_price': Decimal('185.0738'),
#   'low_price': Decimal('184.9245'),
#   'number_of_trades': None,
#   'volume': 513469,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 17, 15, tzinfo=<UTC>)},
#  {'open_price': Decimal('185.0241'),
#   'close_price': Decimal('185.0440'),
#   'high_price': Decimal('185.0639'),
#   'low_price': Decimal('184.9544'),
#   'number_of_trades': None,
#   'volume': 303510,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 17, 10, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.8847'),
#   'close_price': Decimal('185.0154'),
#   'high_price': Decimal('185.0440'),
#   'low_price': Decimal('184.8051'),
#   'number_of_trades': None,
#   'volume': 266737,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 17, 5, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7803'),
#   'close_price': Decimal('184.8947'),
#   'high_price': Decimal('184.9146'),
#   'low_price': Decimal('184.7075'),
#   'number_of_trades': None,
#   'volume': 269513,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 17, 0, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6625'),
#   'close_price': Decimal('184.7803'),
#   'high_price': Decimal('184.9544'),
#   'low_price': Decimal('184.6559'),
#   'number_of_trades': None,
#   'volume': 285521,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 16, 55, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6459'),
#   'close_price': Decimal('184.6559'),
#   'high_price': Decimal('184.7305'),
#   'low_price': Decimal('184.5165'),
#   'number_of_trades': None,
#   'volume': 279867,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 16, 50, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.7205'),
#   'close_price': Decimal('184.6409'),
#   'high_price': Decimal('184.8051'),
#   'low_price': Decimal('184.5962'),
#   'number_of_trades': None,
#   'volume': 327291,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 16, 45, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.6658'),
#   'close_price': Decimal('184.7203'),
#   'high_price': Decimal('184.7454'),
#   'low_price': Decimal('184.5414'),
#   'number_of_trades': None,
#   'volume': 275619,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 1, 31, 16, 40, tzinfo=<UTC>)}]

# %%
dataset_b
# Out:
# [{'open_price': 129.6,
#   'close_price': 129.99,
#   'high_price': 130.3,
#   'low_price': 129.6,
#   'number_of_trades': 364,
#   'volume': 15363,
#   'volume_weighted_average': 129.849,
#   'time': datetime.datetime(2023, 1, 9, 9, 0, tzinfo=<UTC>)},
#  {'open_price': 130.08,
#   'close_price': 129.95,
#   'high_price': 130.17,
#   'low_price': 129.9,
#   'number_of_trades': 291,
#   'volume': 13603,
#   'volume_weighted_average': 130.0603,
#   'time': datetime.datetime(2023, 1, 9, 9, 5, tzinfo=<UTC>)},
#  {'open_price': 129.9,
#   'close_price': 130,
#   'high_price': 130.02,
#   'low_price': 129.9,
#   'number_of_trades': 113,
#   'volume': 3064,
#   'volume_weighted_average': 129.979,
#   'time': datetime.datetime(2023, 1, 9, 9, 10, tzinfo=<UTC>)},
#  {'open_price': 130.22,
#   'close_price': 130.19,
#   'high_price': 130.23,
#   'low_price': 130.19,
#   'number_of_trades': 73,
#   'volume': 2519,
#   'volume_weighted_average': 130.205,
#   'time': datetime.datetime(2023, 1, 9, 9, 15, tzinfo=<UTC>)},
#  {'open_price': 130.24,
#   'close_price': 130.15,
#   'high_price': 130.25,
#   'low_price': 130.15,
#   'number_of_trades': 131,
#   'volume': 5038,
#   'volume_weighted_average': 130.2103,
#   'time': datetime.datetime(2023, 1, 9, 9, 20, tzinfo=<UTC>)},
#  {'open_price': 130.2,
#   'close_price': 130.2,
#   'high_price': 130.33,
#   'low_price': 130.2,
#   'number_of_trades': 207,
#   'volume': 7838,
#   'volume_weighted_average': 130.2531,
#   'time': datetime.datetime(2023, 1, 9, 9, 25, tzinfo=<UTC>)},
#  {'open_price': 130.2,
#   'close_price': 130.24,
#   'high_price': 130.24,
#   'low_price': 130.19,
#   'number_of_trades': 41,
#   'volume': 1832,
#   'volume_weighted_average': 130.2074,
#   'time': datetime.datetime(2023, 1, 9, 9, 30, tzinfo=<UTC>)},
#  {'open_price': 130.25,
#   'close_price': 130.19,
#   'high_price': 130.25,
#   'low_price': 130.19,
#   'number_of_trades': 59,
#   'volume': 1813,
#   'volume_weighted_average': 130.2131,
#   'time': datetime.datetime(2023, 1, 9, 9, 35, tzinfo=<UTC>)},
#  {'open_price': 130.2,
#   'close_price': 130.3,
#   'high_price': 130.3,
#   'low_price': 130.2,
#   'number_of_trades': 114,
#   'volume': 3966,
#   'volume_weighted_average': 130.2565,
#   'time': datetime.datetime(2023, 1, 9, 9, 40, tzinfo=<UTC>)},
#  {'open_price': 130.3,
#   'close_price': 130.47,
#   'high_price': 130.47,
#   'low_price': 130.3,
#   'number_of_trades': 86,
#   'volume': 3713,
#   'volume_weighted_average': 130.4049,
#   'time': datetime.datetime(2023, 1, 9, 9, 45, tzinfo=<UTC>)},
#  {'open_price': 130.48,
#   'close_price': 130.33,
#   'high_price': 130.5,
#   'low_price': 130.3,
#   'number_of_trades': 206,
#   'volume': 12772,
#   'volume_weighted_average': 130.4084,
#   'time': datetime.datetime(2023, 1, 9, 9, 50, tzinfo=<UTC>)},
#  {'open_price': 130.35,
#   'close_price': 130.29,
#   'high_price': 130.35,
#   'low_price': 130.29,
#   'number_of_trades': 79,
#   'volume': 2954,
#   'volume_weighted_average': 130.3244,
#   'time': datetime.datetime(2023, 1, 9, 9, 55, tzinfo=<UTC>)},
#  {'open_price': 130.26,
#   'close_price': 130.2,
#   'high_price': 130.26,
#   'low_price': 130.2,
#   'number_of_trades': 157,
#   'volume': 4000,
#   'volume_weighted_average': 130.2353,
#   'time': datetime.datetime(2023, 1, 9, 10, 0, tzinfo=<UTC>)},
#  {'open_price': 130.23,
#   'close_price': 130.22,
#   'high_price': 130.27,
#   'low_price': 130.21,
#   'number_of_trades': 58,
#   'volume': 1430,
#   'volume_weighted_average': 130.2343,
#   'time': datetime.datetime(2023, 1, 9, 10, 5, tzinfo=<UTC>)},
#  {'open_price': 130.33,
#   'close_price': 130.35,
#   'high_price': 130.35,
#   'low_price': 130.3,
#   'number_of_trades': 39,
#   'volume': 1222,
#   'volume_weighted_average': 130.3323,
#   'time': datetime.datetime(2023, 1, 9, 10, 10, tzinfo=<UTC>)},
#  {'open_price': 130.35,
#   'close_price': 130.42,
#   'high_price': 130.42,
#   'low_price': 130.3,
#   'number_of_trades': 93,
#   'volume': 3522,
#   'volume_weighted_average': 130.3342,
#   'time': datetime.datetime(2023, 1, 9, 10, 15, tzinfo=<UTC>)},
#  {'open_price': 130.45,
#   'close_price': 130.44,
#   'high_price': 130.49,
#   'low_price': 130.44,
#   'number_of_trades': 65,
#   'volume': 3234,
#   'volume_weighted_average': 130.4644,
#   'time': datetime.datetime(2023, 1, 9, 10, 20, tzinfo=<UTC>)},
#  {'open_price': 130.44,
#   'close_price': 130.35,
#   'high_price': 130.5,
#   'low_price': 130.35,
#   'number_of_trades': 146,
#   'volume': 4990,
#   'volume_weighted_average': 130.4446,
#   'time': datetime.datetime(2023, 1, 9, 10, 25, tzinfo=<UTC>)},
#  {'open_price': 130.4,
#   'close_price': 130.2,
#   'high_price': 130.4,
#   'low_price': 130.2,
#   'number_of_trades': 150,
#   'volume': 5077,
#   'volume_weighted_average': 130.2853,
#   'time': datetime.datetime(2023, 1, 9, 10, 30, tzinfo=<UTC>)},
#  {'open_price': 130.26,
#   'close_price': 130.35,
#   'high_price': 130.35,
#   'low_price': 130.26,
#   'number_of_trades': 42,
#   'volume': 1046,
#   'volume_weighted_average': 130.3096,
#   'time': datetime.datetime(2023, 1, 9, 10, 35, tzinfo=<UTC>)},
#  {'open_price': 130.27,
#   'close_price': 130.17,
#   'high_price': 130.27,
#   'low_price': 130.17,
#   'number_of_trades': 62,
#   'volume': 1630,
#   'volume_weighted_average': 130.2367,
#   'time': datetime.datetime(2023, 1, 9, 10, 40, tzinfo=<UTC>)},
#  {'open_price': 130.18,
#   'close_price': 130.18,
#   'high_price': 130.18,
#   'low_price': 130.18,
#   'number_of_trades': 9,
#   'volume': 235,
#   'volume_weighted_average': 130.1834,
#   'time': datetime.datetime(2023, 1, 9, 10, 45, tzinfo=<UTC>)},
#  {'open_price': 130.17,
#   'close_price': 130.19,
#   'high_price': 130.19,
#   'low_price': 130.15,
#   'number_of_trades': 96,
#   'volume': 2493,
#   'volume_weighted_average': 130.1435,
#   'time': datetime.datetime(2023, 1, 9, 10, 50, tzinfo=<UTC>)},
#  {'open_price': 130.24,
#   'close_price': 130.25,
#   'high_price': 130.25,
#   'low_price': 130.2,
#   'number_of_trades': 62,
#   'volume': 1900,
#   'volume_weighted_average': 130.2307,
#   'time': datetime.datetime(2023, 1, 9, 10, 55, tzinfo=<UTC>)},
#  {'open_price': 130.21,
#   'close_price': 130.34,
#   'high_price': 130.35,
#   'low_price': 130.21,
#   'number_of_trades': 74,
#   'volume': 2615,
#   'volume_weighted_average': 130.2836,
#   'time': datetime.datetime(2023, 1, 9, 11, 0, tzinfo=<UTC>)},
#  {'open_price': 130.3,
#   'close_price': 130.28,
#   'high_price': 130.34,
#   'low_price': 130.28,
#   'number_of_trades': 29,
#   'volume': 1496,
#   'volume_weighted_average': 130.2982,
#   'time': datetime.datetime(2023, 1, 9, 11, 5, tzinfo=<UTC>)},
#  {'open_price': 130.25,
#   'close_price': 130.16,
#   'high_price': 130.25,
#   'low_price': 130.15,
#   'number_of_trades': 103,
#   'volume': 3642,
#   'volume_weighted_average': 130.1848,
#   'time': datetime.datetime(2023, 1, 9, 11, 10, tzinfo=<UTC>)},
#  {'open_price': 130.17,
#   'close_price': 130.12,
#   'high_price': 130.18,
#   'low_price': 130.12,
#   'number_of_trades': 127,
#   'volume': 2827,
#   'volume_weighted_average': 130.1616,
#   'time': datetime.datetime(2023, 1, 9, 11, 15, tzinfo=<UTC>)},
#  {'open_price': 130.12,
#   'close_price': 130.19,
#   'high_price': 130.19,
#   'low_price': 130.02,
#   'number_of_trades': 146,
#   'volume': 4445,
#   'volume_weighted_average': 130.0909,
#   'time': datetime.datetime(2023, 1, 9, 11, 20, tzinfo=<UTC>)},
#  {'open_price': 130.18,
#   'close_price': 130.15,
#   'high_price': 130.2,
#   'low_price': 130.15,
#   'number_of_trades': 47,
#   'volume': 1296,
#   'volume_weighted_average': 130.1837,
#   'time': datetime.datetime(2023, 1, 9, 11, 25, tzinfo=<UTC>)},
#  {'open_price': 130.11,
#   'close_price': 130.11,
#   'high_price': 130.11,
#   'low_price': 130.11,
#   'number_of_trades': 56,
#   'volume': 1209,
#   'volume_weighted_average': 130.1233,
#   'time': datetime.datetime(2023, 1, 9, 11, 30, tzinfo=<UTC>)},
#  {'open_price': 130.17,
#   'close_price': 130.17,
#   'high_price': 130.17,
#   'low_price': 130.17,
#   'number_of_trades': 18,
#   'volume': 887,
#   'volume_weighted_average': 130.1712,
#   'time': datetime.datetime(2023, 1, 9, 11, 35, tzinfo=<UTC>)},
#  {'open_price': 130.14,
#   'close_price': 130.15,
#   'high_price': 130.15,
#   'low_price': 130.14,
#   'number_of_trades': 48,
#   'volume': 1576,
#   'volume_weighted_average': 130.1431,
#   'time': datetime.datetime(2023, 1, 9, 11, 40, tzinfo=<UTC>)},
#  {'open_price': 130.16,
#   'close_price': 130.18,
#   'high_price': 130.18,
#   'low_price': 130.16,
#   'number_of_trades': 20,
#   'volume': 501,
#   'volume_weighted_average': 130.1671,
#   'time': datetime.datetime(2023, 1, 9, 11, 45, tzinfo=<UTC>)},
#  {'open_price': 130.24,
#   'close_price': 130.3,
#   'high_price': 130.32,
#   'low_price': 130.24,
#   'number_of_trades': 59,
#   'volume': 2501,
#   'volume_weighted_average': 130.2785,
#   'time': datetime.datetime(2023, 1, 9, 11, 50, tzinfo=<UTC>)},
#  {'open_price': 130.3,
#   'close_price': 130.22,
#   'high_price': 130.32,
#   'low_price': 130.22,
#   'number_of_trades': 191,
#   'volume': 8948,
#   'volume_weighted_average': 130.2835,
#   'time': datetime.datetime(2023, 1, 9, 11, 55, tzinfo=<UTC>)},
#  {'open_price': 130.25,
#   'close_price': 130.35,
#   'high_price': 130.35,
#   'low_price': 130.16,
#   'number_of_trades': 529,
#   'volume': 32099,
#   'volume_weighted_average': 130.2822,
#   'time': datetime.datetime(2023, 1, 9, 12, 0, tzinfo=<UTC>)},
#  {'open_price': 130.35,
#   'close_price': 130.26,
#   'high_price': 130.36,
#   'low_price': 130.26,
#   'number_of_trades': 229,
#   'volume': 19647,
#   'volume_weighted_average': 130.2855,
#   'time': datetime.datetime(2023, 1, 9, 12, 5, tzinfo=<UTC>)},
#  {'open_price': 130.22,
#   'close_price': 130.27,
#   'high_price': 130.3,
#   'low_price': 130.21,
#   'number_of_trades': 177,
#   'volume': 11661,
#   'volume_weighted_average': 130.2586,
#   'time': datetime.datetime(2023, 1, 9, 12, 10, tzinfo=<UTC>)},
#  {'open_price': 130.27,
#   'close_price': 130.26,
#   'high_price': 130.27,
#   'low_price': 130.21,
#   'number_of_trades': 152,
#   'volume': 7245,
#   'volume_weighted_average': 130.2453,
#   'time': datetime.datetime(2023, 1, 9, 12, 15, tzinfo=<UTC>)},
#  {'open_price': 130.24,
#   'close_price': 130.24,
#   'high_price': 130.27,
#   'low_price': 130.22,
#   'number_of_trades': 143,
#   'volume': 7962,
#   'volume_weighted_average': 130.2386,
#   'time': datetime.datetime(2023, 1, 9, 12, 20, tzinfo=<UTC>)},
#  {'open_price': 130.23,
#   'close_price': 130.2,
#   'high_price': 130.24,
#   'low_price': 130.2,
#   'number_of_trades': 169,
#   'volume': 12411,
#   'volume_weighted_average': 130.218,
#   'time': datetime.datetime(2023, 1, 9, 12, 25, tzinfo=<UTC>)},
#  {'open_price': 130.19,
#   'close_price': 130.3,
#   'high_price': 130.34,
#   'low_price': 130.19,
#   'number_of_trades': 236,
#   'volume': 15092,
#   'volume_weighted_average': 130.2871,
#   'time': datetime.datetime(2023, 1, 9, 12, 30, tzinfo=<UTC>)},
#  {'open_price': 130.3,
#   'close_price': 130.36,
#   'high_price': 130.4,
#   'low_price': 130.3,
#   'number_of_trades': 222,
#   'volume': 12176,
#   'volume_weighted_average': 130.3568,
#   'time': datetime.datetime(2023, 1, 9, 12, 35, tzinfo=<UTC>)},
#  {'open_price': 130.32,
#   'close_price': 130.28,
#   'high_price': 130.33,
#   'low_price': 130.25,
#   'number_of_trades': 267,
#   'volume': 8678,
#   'volume_weighted_average': 130.302,
#   'time': datetime.datetime(2023, 1, 9, 12, 40, tzinfo=<UTC>)},
#  {'open_price': 130.28,
#   'close_price': 130.25,
#   'high_price': 130.34,
#   'low_price': 130.25,
#   'number_of_trades': 265,
#   'volume': 8961,
#   'volume_weighted_average': 130.3003,
#   'time': datetime.datetime(2023, 1, 9, 12, 45, tzinfo=<UTC>)},
#  {'open_price': 130.23,
#   'close_price': 130.25,
#   'high_price': 130.25,
#   'low_price': 130.19,
#   'number_of_trades': 185,
#   'volume': 10055,
#   'volume_weighted_average': 130.2219,
#   'time': datetime.datetime(2023, 1, 9, 12, 50, tzinfo=<UTC>)},
#  {'open_price': 130.24,
#   'close_price': 130.25,
#   'high_price': 130.27,
#   'low_price': 130.24,
#   'number_of_trades': 110,
#   'volume': 3834,
#   'volume_weighted_average': 130.2489,
#   'time': datetime.datetime(2023, 1, 9, 12, 55, tzinfo=<UTC>)},
#  {'open_price': 130.2,
#   'close_price': 130.08,
#   'high_price': 130.63,
#   'low_price': 130.08,
#   'number_of_trades': 2122,
#   'volume': 84470,
#   'volume_weighted_average': 130.2478,
#   'time': datetime.datetime(2023, 1, 9, 13, 0, tzinfo=<UTC>)},
#  {'open_price': 130.0548,
#   'close_price': 130.06,
#   'high_price': 130.06,
#   'low_price': 129.955,
#   'number_of_trades': 840,
#   'volume': 34177,
#   'volume_weighted_average': 130.0096,
#   'time': datetime.datetime(2023, 1, 9, 13, 5, tzinfo=<UTC>)},
#  {'open_price': 130.055,
#   'close_price': 130.12,
#   'high_price': 130.14,
#   'low_price': 130.02,
#   'number_of_trades': 292,
#   'volume': 13320,
#   'volume_weighted_average': 130.0831,
#   'time': datetime.datetime(2023, 1, 9, 13, 10, tzinfo=<UTC>)},
#  {'open_price': 130.11,
#   'close_price': 130.25,
#   'high_price': 130.26,
#   'low_price': 130.11,
#   'number_of_trades': 358,
#   'volume': 21810,
#   'volume_weighted_average': 130.1844,
#   'time': datetime.datetime(2023, 1, 9, 13, 15, tzinfo=<UTC>)},
#  {'open_price': 130.27,
#   'close_price': 130.3,
#   'high_price': 130.41,
#   'low_price': 130.24,
#   'number_of_trades': 639,
#   'volume': 55023,
#   'volume_weighted_average': 130.2105,
#   'time': datetime.datetime(2023, 1, 9, 13, 20, tzinfo=<UTC>)},
#  {'open_price': 130.29,
#   'close_price': 130.32,
#   'high_price': 130.34,
#   'low_price': 130.25,
#   'number_of_trades': 458,
#   'volume': 32097,
#   'volume_weighted_average': 130.3014,
#   'time': datetime.datetime(2023, 1, 9, 13, 25, tzinfo=<UTC>)},
#  {'open_price': 130.34,
#   'close_price': 130.45,
#   'high_price': 130.5,
#   'low_price': 130.28,
#   'number_of_trades': 838,
#   'volume': 53379,
#   'volume_weighted_average': 130.4146,
#   'time': datetime.datetime(2023, 1, 9, 13, 30, tzinfo=<UTC>)},
#  {'open_price': 130.45,
#   'close_price': 130.31,
#   'high_price': 130.45,
#   'low_price': 130.31,
#   'number_of_trades': 535,
#   'volume': 23176,
#   'volume_weighted_average': 130.3891,
#   'time': datetime.datetime(2023, 1, 9, 13, 35, tzinfo=<UTC>)},
#  {'open_price': 130.31,
#   'close_price': 130.29,
#   'high_price': 130.42,
#   'low_price': 130.23,
#   'number_of_trades': 558,
#   'volume': 31638,
#   'volume_weighted_average': 130.3279,
#   'time': datetime.datetime(2023, 1, 9, 13, 40, tzinfo=<UTC>)},
#  {'open_price': 130.32,
#   'close_price': 130.26,
#   'high_price': 130.37,
#   'low_price': 130.25,
#   'number_of_trades': 385,
#   'volume': 19789,
#   'volume_weighted_average': 130.3322,
#   'time': datetime.datetime(2023, 1, 9, 13, 45, tzinfo=<UTC>)},
#  {'open_price': 130.32,
#   'close_price': 130.3,
#   'high_price': 130.35,
#   'low_price': 130.26,
#   'number_of_trades': 368,
#   'volume': 19743,
#   'volume_weighted_average': 130.3153,
#   'time': datetime.datetime(2023, 1, 9, 13, 50, tzinfo=<UTC>)},
#  {'open_price': 130.33,
#   'close_price': 130.2,
#   'high_price': 130.33,
#   'low_price': 130.2,
#   'number_of_trades': 636,
#   'volume': 39366,
#   'volume_weighted_average': 130.2742,
#   'time': datetime.datetime(2023, 1, 9, 13, 55, tzinfo=<UTC>)},
#  {'open_price': 130.24,
#   'close_price': 130.28,
#   'high_price': 130.32,
#   'low_price': 130.13,
#   'number_of_trades': 585,
#   'volume': 22488,
#   'volume_weighted_average': 130.2137,
#   'time': datetime.datetime(2023, 1, 9, 14, 0, tzinfo=<UTC>)},
#  {'open_price': 130.2917,
#   'close_price': 130.23,
#   'high_price': 130.32,
#   'low_price': 130.21,
#   'number_of_trades': 486,
#   'volume': 16171,
#   'volume_weighted_average': 130.2642,
#   'time': datetime.datetime(2023, 1, 9, 14, 5, tzinfo=<UTC>)},
#  {'open_price': 130.25,
#   'close_price': 130.27,
#   'high_price': 130.29,
#   'low_price': 130.211,
#   'number_of_trades': 457,
#   'volume': 19282,
#   'volume_weighted_average': 130.2468,
#   'time': datetime.datetime(2023, 1, 9, 14, 10, tzinfo=<UTC>)},
#  {'open_price': 130.3,
#   'close_price': 130.31,
#   'high_price': 130.36,
#   'low_price': 130.223,
#   'number_of_trades': 517,
#   'volume': 32185,
#   'volume_weighted_average': 130.2776,
#   'time': datetime.datetime(2023, 1, 9, 14, 15, tzinfo=<UTC>)},
#  {'open_price': 130.35,
#   'close_price': 130.52,
#   'high_price': 130.57,
#   'low_price': 130.29,
#   'number_of_trades': 704,
#   'volume': 45321,
#   'volume_weighted_average': 130.429,
#   'time': datetime.datetime(2023, 1, 9, 14, 20, tzinfo=<UTC>)},
#  {'open_price': 130.45,
#   'close_price': 130.52,
#   'high_price': 130.54,
#   'low_price': 130.21,
#   'number_of_trades': 908,
#   'volume': 59327,
#   'volume_weighted_average': 130.3513,
#   'time': datetime.datetime(2023, 1, 9, 14, 25, tzinfo=<UTC>)},
#  {'open_price': 130.465,
#   'close_price': 131.12,
#   'high_price': 131.44,
#   'low_price': 130.465,
#   'number_of_trades': 54724,
#   'volume': 3119913.0,
#   'volume_weighted_average': 130.913,
#   'time': datetime.datetime(2023, 1, 9, 14, 30, tzinfo=<UTC>)},
#  {'open_price': 131.115,
#   'close_price': 130.98,
#   'high_price': 131.18,
#   'low_price': 130.66,
#   'number_of_trades': 28254,
#   'volume': 1292566.0,
#   'volume_weighted_average': 130.8879,
#   'time': datetime.datetime(2023, 1, 9, 14, 35, tzinfo=<UTC>)},
#  {'open_price': 130.9721,
#   'close_price': 131.05,
#   'high_price': 131.14,
#   'low_price': 130.53,
#   'number_of_trades': 13258,
#   'volume': 1475390.0,
#   'volume_weighted_average': 130.8787,
#   'time': datetime.datetime(2023, 1, 9, 14, 40, tzinfo=<UTC>)},
#  {'open_price': 131.05,
#   'close_price': 131.36,
#   'high_price': 131.75,
#   'low_price': 131.0458,
#   'number_of_trades': 15349,
#   'volume': 1478610.0,
#   'volume_weighted_average': 131.4036,
#   'time': datetime.datetime(2023, 1, 9, 14, 45, tzinfo=<UTC>)},
#  {'open_price': 131.3512,
#   'close_price': 131.7,
#   'high_price': 131.7471,
#   'low_price': 131.28,
#   'number_of_trades': 13177,
#   'volume': 1285626.0,
#   'volume_weighted_average': 131.5222,
#   'time': datetime.datetime(2023, 1, 9, 14, 50, tzinfo=<UTC>)},
#  {'open_price': 131.7008,
#   'close_price': 132.015,
#   'high_price': 132.06,
#   'low_price': 131.59,
#   'number_of_trades': 14371,
#   'volume': 1318430.0,
#   'volume_weighted_average': 131.839,
#   'time': datetime.datetime(2023, 1, 9, 14, 55, tzinfo=<UTC>)},
#  {'open_price': 132.01,
#   'close_price': 132.1899,
#   'high_price': 132.32,
#   'low_price': 132.01,
#   'number_of_trades': 13413,
#   'volume': 1284119.0,
#   'volume_weighted_average': 132.1783,
#   'time': datetime.datetime(2023, 1, 9, 15, 0, tzinfo=<UTC>)},
#  {'open_price': 132.18,
#   'close_price': 132.295,
#   'high_price': 132.3542,
#   'low_price': 131.3218,
#   'number_of_trades': 12840,
#   'volume': 1411706.0,
#   'volume_weighted_average': 132.1889,
#   'time': datetime.datetime(2023, 1, 9, 15, 5, tzinfo=<UTC>)},
#  {'open_price': 132.295,
#   'close_price': 132.13,
#   'high_price': 132.63,
#   'low_price': 132.09,
#   'number_of_trades': 13169,
#   'volume': 1246933.0,
#   'volume_weighted_average': 132.3653,
#   'time': datetime.datetime(2023, 1, 9, 15, 10, tzinfo=<UTC>)},
#  {'open_price': 132.145,
#   'close_price': 132.035,
#   'high_price': 132.31,
#   'low_price': 131.96,
#   'number_of_trades': 10032,
#   'volume': 1020314.0,
#   'volume_weighted_average': 132.1421,
#   'time': datetime.datetime(2023, 1, 9, 15, 15, tzinfo=<UTC>)},
#  {'open_price': 132.04,
#   'close_price': 132.48,
#   'high_price': 132.51,
#   'low_price': 131.98,
#   'number_of_trades': 9327,
#   'volume': 1149285.0,
#   'volume_weighted_average': 132.2486,
#   'time': datetime.datetime(2023, 1, 9, 15, 20, tzinfo=<UTC>)},
#  {'open_price': 132.475,
#   'close_price': 132.565,
#   'high_price': 132.735,
#   'low_price': 132.31,
#   'number_of_trades': 10612,
#   'volume': 1311746.0,
#   'volume_weighted_average': 132.5451,
#   'time': datetime.datetime(2023, 1, 9, 15, 25, tzinfo=<UTC>)},
#  {'open_price': 132.575,
#   'close_price': 132.6305,
#   'high_price': 132.75,
#   'low_price': 132.4636,
#   'number_of_trades': 7990,
#   'volume': 889559,
#   'volume_weighted_average': 132.6271,
#   'time': datetime.datetime(2023, 1, 9, 15, 30, tzinfo=<UTC>)},
#  {'open_price': 132.63,
#   'close_price': 132.7684,
#   'high_price': 132.835,
#   'low_price': 132.56,
#   'number_of_trades': 8751,
#   'volume': 914085,
#   'volume_weighted_average': 132.7335,
#   'time': datetime.datetime(2023, 1, 9, 15, 35, tzinfo=<UTC>)},
#  {'open_price': 132.765,
#   'close_price': 132.735,
#   'high_price': 132.8375,
#   'low_price': 132.6088,
#   'number_of_trades': 7098,
#   'volume': 722550,
#   'volume_weighted_average': 132.7122,
#   'time': datetime.datetime(2023, 1, 9, 15, 40, tzinfo=<UTC>)},
#  {'open_price': 132.73,
#   'close_price': 133.055,
#   'high_price': 133.14,
#   'low_price': 132.72,
#   'number_of_trades': 10597,
#   'volume': 1088753.0,
#   'volume_weighted_average': 132.9591,
#   'time': datetime.datetime(2023, 1, 9, 15, 45, tzinfo=<UTC>)},
#  {'open_price': 133.05,
#   'close_price': 132.9588,
#   'high_price': 133.12,
#   'low_price': 132.82,
#   'number_of_trades': 7109,
#   'volume': 826724,
#   'volume_weighted_average': 132.9679,
#   'time': datetime.datetime(2023, 1, 9, 15, 50, tzinfo=<UTC>)},
#  {'open_price': 132.955,
#   'close_price': 132.74,
#   'high_price': 133.02,
#   'low_price': 132.66,
#   'number_of_trades': 7347,
#   'volume': 841415,
#   'volume_weighted_average': 132.8314,
#   'time': datetime.datetime(2023, 1, 9, 15, 55, tzinfo=<UTC>)},
#  {'open_price': 132.74,
#   'close_price': 132.9167,
#   'high_price': 133.01,
#   'low_price': 132.67,
#   'number_of_trades': 7621,
#   'volume': 826751,
#   'volume_weighted_average': 132.8293,
#   'time': datetime.datetime(2023, 1, 9, 16, 0, tzinfo=<UTC>)},
#  {'open_price': 132.91,
#   'close_price': 133.275,
#   'high_price': 133.34,
#   'low_price': 132.885,
#   'number_of_trades': 9406,
#   'volume': 1080302.0,
#   'volume_weighted_average': 133.1548,
#   'time': datetime.datetime(2023, 1, 9, 16, 5, tzinfo=<UTC>)},
#  {'open_price': 133.28,
#   'close_price': 133.2101,
#   'high_price': 133.3,
#   'low_price': 133.11,
#   'number_of_trades': 6505,
#   'volume': 772883,
#   'volume_weighted_average': 133.2065,
#   'time': datetime.datetime(2023, 1, 9, 16, 10, tzinfo=<UTC>)},
#  {'open_price': 133.23,
#   'close_price': 133.095,
#   'high_price': 133.41,
#   'low_price': 133.06,
#   'number_of_trades': 7573,
#   'volume': 903820,
#   'volume_weighted_average': 133.2391,
#   'time': datetime.datetime(2023, 1, 9, 16, 15, tzinfo=<UTC>)},
#  {'open_price': 133.1,
#   'close_price': 133.115,
#   'high_price': 133.15,
#   'low_price': 132.97,
#   'number_of_trades': 6459,
#   'volume': 747259,
#   'volume_weighted_average': 133.0537,
#   'time': datetime.datetime(2023, 1, 9, 16, 20, tzinfo=<UTC>)},
#  {'open_price': 133.11,
#   'close_price': 133.085,
#   'high_price': 133.24,
#   'low_price': 133.01,
#   'number_of_trades': 6591,
#   'volume': 715087,
#   'volume_weighted_average': 133.1352,
#   'time': datetime.datetime(2023, 1, 9, 16, 25, tzinfo=<UTC>)},
#  {'open_price': 133.09,
#   'close_price': 132.8899,
#   'high_price': 133.18,
#   'low_price': 132.85,
#   'number_of_trades': 7010,
#   'volume': 888561,
#   'volume_weighted_average': 133.0012,
#   'time': datetime.datetime(2023, 1, 9, 16, 30, tzinfo=<UTC>)},
#  {'open_price': 132.88,
#   'close_price': 132.84,
#   'high_price': 133.03,
#   'low_price': 132.8,
#   'number_of_trades': 5627,
#   'volume': 582810,
#   'volume_weighted_average': 132.9224,
#   'time': datetime.datetime(2023, 1, 9, 16, 35, tzinfo=<UTC>)},
#  {'open_price': 132.845,
#   'close_price': 132.97,
#   'high_price': 133,
#   'low_price': 132.8,
#   'number_of_trades': 5696,
#   'volume': 569150,
#   'volume_weighted_average': 132.8951,
#   'time': datetime.datetime(2023, 1, 9, 16, 40, tzinfo=<UTC>)},
#  {'open_price': 132.9679,
#   'close_price': 132.915,
#   'high_price': 133.0289,
#   'low_price': 132.81,
#   'number_of_trades': 4753,
#   'volume': 458142,
#   'volume_weighted_average': 132.9489,
#   'time': datetime.datetime(2023, 1, 9, 16, 45, tzinfo=<UTC>)},
#  {'open_price': 132.92,
#   'close_price': 133.08,
#   'high_price': 133.12,
#   'low_price': 132.88,
#   'number_of_trades': 6442,
#   'volume': 657633,
#   'volume_weighted_average': 133.0297,
#   'time': datetime.datetime(2023, 1, 9, 16, 50, tzinfo=<UTC>)},
#  {'open_price': 133.06,
#   'close_price': 132.945,
#   'high_price': 133.08,
#   'low_price': 132.85,
#   'number_of_trades': 5249,
#   'volume': 528015,
#   'volume_weighted_average': 132.968,
#   'time': datetime.datetime(2023, 1, 9, 16, 55, tzinfo=<UTC>)},
#  {'open_price': 132.94,
#   'close_price': 132.78,
#   'high_price': 132.955,
#   'low_price': 132.68,
#   'number_of_trades': 5615,
#   'volume': 583598,
#   'volume_weighted_average': 132.7887,
#   'time': datetime.datetime(2023, 1, 9, 17, 0, tzinfo=<UTC>)},
#  {'open_price': 132.79,
#   'close_price': 132.71,
#   'high_price': 132.815,
#   'low_price': 132.57,
#   'number_of_trades': 5144,
#   'volume': 523725,
#   'volume_weighted_average': 132.694,
#   'time': datetime.datetime(2023, 1, 9, 17, 5, tzinfo=<UTC>)},
#  {'open_price': 132.71,
#   'close_price': 132.82,
#   'high_price': 132.87,
#   'low_price': 132.71,
#   'number_of_trades': 4729,
#   'volume': 490225,
#   'volume_weighted_average': 132.7971,
#   'time': datetime.datetime(2023, 1, 9, 17, 10, tzinfo=<UTC>)},
#  {'open_price': 132.8101,
#   'close_price': 132.78,
#   'high_price': 132.8415,
#   'low_price': 132.6,
#   'number_of_trades': 4680,
#   'volume': 503052,
#   'volume_weighted_average': 132.7504,
#   'time': datetime.datetime(2023, 1, 9, 17, 15, tzinfo=<UTC>)},
#  {'open_price': 132.785,
#   'close_price': 132.7668,
#   'high_price': 132.82,
#   'low_price': 132.655,
#   'number_of_trades': 4172,
#   'volume': 445983,
#   'volume_weighted_average': 132.7443,
#   'time': datetime.datetime(2023, 1, 9, 17, 20, tzinfo=<UTC>)},
#  {'open_price': 132.7601,
#   'close_price': 132.745,
#   'high_price': 132.835,
#   'low_price': 132.65,
#   'number_of_trades': 3953,
#   'volume': 411250,
#   'volume_weighted_average': 132.7406,
#   'time': datetime.datetime(2023, 1, 9, 17, 25, tzinfo=<UTC>)},
#  {'open_price': 132.74,
#   'close_price': 132.67,
#   'high_price': 132.83,
#   'low_price': 132.66,
#   'number_of_trades': 3771,
#   'volume': 328833,
#   'volume_weighted_average': 132.7458,
#   'time': datetime.datetime(2023, 1, 9, 17, 30, tzinfo=<UTC>)},
#  {'open_price': 132.672,
#   'close_price': 132.4184,
#   'high_price': 132.705,
#   'low_price': 132.41,
#   'number_of_trades': 5421,
#   'volume': 531799,
#   'volume_weighted_average': 132.5419,
#   'time': datetime.datetime(2023, 1, 9, 17, 35, tzinfo=<UTC>)},
#  {'open_price': 132.42,
#   'close_price': 132.26,
#   'high_price': 132.42,
#   'low_price': 132.25,
#   'number_of_trades': 5087,
#   'volume': 476515,
#   'volume_weighted_average': 132.3521,
#   'time': datetime.datetime(2023, 1, 9, 17, 40, tzinfo=<UTC>)},
#  {'open_price': 132.26,
#   'close_price': 132.43,
#   'high_price': 132.53,
#   'low_price': 132.255,
#   'number_of_trades': 5502,
#   'volume': 1396574.0,
#   'volume_weighted_average': 132.4184,
#   'time': datetime.datetime(2023, 1, 9, 17, 45, tzinfo=<UTC>)},
#  {'open_price': 132.43,
#   'close_price': 132.425,
#   'high_price': 132.5,
#   'low_price': 132.38,
#   'number_of_trades': 3901,
#   'volume': 323683,
#   'volume_weighted_average': 132.4255,
#   'time': datetime.datetime(2023, 1, 9, 17, 50, tzinfo=<UTC>)},
#  {'open_price': 132.428,
#   'close_price': 132.459,
#   'high_price': 132.49,
#   'low_price': 132.34,
#   'number_of_trades': 3419,
#   'volume': 326154,
#   'volume_weighted_average': 132.4122,
#   'time': datetime.datetime(2023, 1, 9, 17, 55, tzinfo=<UTC>)},
#  {'open_price': 132.46,
#   'close_price': 132.39,
#   'high_price': 132.64,
#   'low_price': 132.38,
#   'number_of_trades': 4588,
#   'volume': 494034,
#   'volume_weighted_average': 132.5219,
#   'time': datetime.datetime(2023, 1, 9, 18, 0, tzinfo=<UTC>)},
#  {'open_price': 132.3999,
#   'close_price': 132.355,
#   'high_price': 132.5199,
#   'low_price': 132.32,
#   'number_of_trades': 4263,
#   'volume': 420613,
#   'volume_weighted_average': 132.4165,
#   'time': datetime.datetime(2023, 1, 9, 18, 5, tzinfo=<UTC>)},
#  {'open_price': 132.35,
#   'close_price': 132.42,
#   'high_price': 132.43,
#   'low_price': 132.26,
#   'number_of_trades': 4808,
#   'volume': 463546,
#   'volume_weighted_average': 132.3389,
#   'time': datetime.datetime(2023, 1, 9, 18, 10, tzinfo=<UTC>)},
#  {'open_price': 132.4201,
#   'close_price': 132.4501,
#   'high_price': 132.5599,
#   'low_price': 132.37,
#   'number_of_trades': 4175,
#   'volume': 384570,
#   'volume_weighted_average': 132.4564,
#   'time': datetime.datetime(2023, 1, 9, 18, 15, tzinfo=<UTC>)},
#  {'open_price': 132.4507,
#   'close_price': 132.535,
#   'high_price': 132.569,
#   'low_price': 132.425,
#   'number_of_trades': 3795,
#   'volume': 382690,
#   'volume_weighted_average': 132.4999,
#   'time': datetime.datetime(2023, 1, 9, 18, 20, tzinfo=<UTC>)},
#  {'open_price': 132.53,
#   'close_price': 132.495,
#   'high_price': 132.53,
#   'low_price': 132.35,
#   'number_of_trades': 4548,
#   'volume': 439793,
#   'volume_weighted_average': 132.4238,
#   'time': datetime.datetime(2023, 1, 9, 18, 25, tzinfo=<UTC>)},
#  {'open_price': 132.495,
#   'close_price': 132.11,
#   'high_price': 132.5101,
#   'low_price': 132.11,
#   'number_of_trades': 6081,
#   'volume': 556917,
#   'volume_weighted_average': 132.3015,
#   'time': datetime.datetime(2023, 1, 9, 18, 30, tzinfo=<UTC>)},
#  {'open_price': 132.11,
#   'close_price': 131.9789,
#   'high_price': 132.12,
#   'low_price': 131.84,
#   'number_of_trades': 8021,
#   'volume': 770124,
#   'volume_weighted_average': 131.9724,
#   'time': datetime.datetime(2023, 1, 9, 18, 35, tzinfo=<UTC>)},
#  {'open_price': 131.97,
#   'close_price': 131.62,
#   'high_price': 132.005,
#   'low_price': 131.57,
#   'number_of_trades': 7142,
#   'volume': 822938,
#   'volume_weighted_average': 131.7337,
#   'time': datetime.datetime(2023, 1, 9, 18, 40, tzinfo=<UTC>)},
#  {'open_price': 131.62,
#   'close_price': 131.4639,
#   'high_price': 131.625,
#   'low_price': 131.24,
#   'number_of_trades': 7307,
#   'volume': 1000031.0,
#   'volume_weighted_average': 131.4706,
#   'time': datetime.datetime(2023, 1, 9, 18, 45, tzinfo=<UTC>)},
#  {'open_price': 131.45,
#   'close_price': 131.31,
#   'high_price': 131.47,
#   'low_price': 131.2701,
#   'number_of_trades': 5473,
#   'volume': 761537,
#   'volume_weighted_average': 131.3652,
#   'time': datetime.datetime(2023, 1, 9, 18, 50, tzinfo=<UTC>)},
#  {'open_price': 131.3,
#   'close_price': 131.395,
#   'high_price': 131.43,
#   'low_price': 131.19,
#   'number_of_trades': 6269,
#   'volume': 693725,
#   'volume_weighted_average': 131.305,
#   'time': datetime.datetime(2023, 1, 9, 18, 55, tzinfo=<UTC>)},
#  {'open_price': 131.39,
#   'close_price': 131.58,
#   'high_price': 131.726,
#   'low_price': 131.38,
#   'number_of_trades': 6604,
#   'volume': 798205,
#   'volume_weighted_average': 131.6104,
#   'time': datetime.datetime(2023, 1, 9, 19, 0, tzinfo=<UTC>)},
#  {'open_price': 131.575,
#   'close_price': 131.4718,
#   'high_price': 131.59,
#   'low_price': 131.2411,
#   'number_of_trades': 7404,
#   'volume': 813314,
#   'volume_weighted_average': 131.4591,
#   'time': datetime.datetime(2023, 1, 9, 19, 5, tzinfo=<UTC>)},
#  {'open_price': 131.47,
#   'close_price': 131.47,
#   'high_price': 131.55,
#   'low_price': 131.27,
#   'number_of_trades': 6466,
#   'volume': 751795,
#   'volume_weighted_average': 131.4479,
#   'time': datetime.datetime(2023, 1, 9, 19, 10, tzinfo=<UTC>)},
#  {'open_price': 131.465,
#   'close_price': 131.54,
#   'high_price': 131.6,
#   'low_price': 131.41,
#   'number_of_trades': 5697,
#   'volume': 641336,
#   'volume_weighted_average': 131.5112,
#   'time': datetime.datetime(2023, 1, 9, 19, 15, tzinfo=<UTC>)},
#  {'open_price': 131.5415,
#   'close_price': 131.61,
#   'high_price': 131.66,
#   'low_price': 131.495,
#   'number_of_trades': 4524,
#   'volume': 518890,
#   'volume_weighted_average': 131.5762,
#   'time': datetime.datetime(2023, 1, 9, 19, 20, tzinfo=<UTC>)},
#  {'open_price': 131.6099,
#   'close_price': 131.495,
#   'high_price': 131.63,
#   'low_price': 131.3,
#   'number_of_trades': 5657,
#   'volume': 652759,
#   'volume_weighted_average': 131.5131,
#   'time': datetime.datetime(2023, 1, 9, 19, 25, tzinfo=<UTC>)},
#  {'open_price': 131.49,
#   'close_price': 131.359,
#   'high_price': 131.5667,
#   'low_price': 131.245,
#   'number_of_trades': 5019,
#   'volume': 531428,
#   'volume_weighted_average': 131.4234,
#   'time': datetime.datetime(2023, 1, 9, 19, 30, tzinfo=<UTC>)},
#  {'open_price': 131.35,
#   'close_price': 131.01,
#   'high_price': 131.3786,
#   'low_price': 131,
#   'number_of_trades': 6005,
#   'volume': 633644,
#   'volume_weighted_average': 131.1582,
#   'time': datetime.datetime(2023, 1, 9, 19, 35, tzinfo=<UTC>)},
#  {'open_price': 131.0101,
#   'close_price': 131.09,
#   'high_price': 131.135,
#   'low_price': 130.95,
#   'number_of_trades': 5722,
#   'volume': 562121,
#   'volume_weighted_average': 131.0307,
#   'time': datetime.datetime(2023, 1, 9, 19, 40, tzinfo=<UTC>)},
#  {'open_price': 131.09,
#   'close_price': 130.96,
#   'high_price': 131.15,
#   'low_price': 130.865,
#   'number_of_trades': 5218,
#   'volume': 512560,
#   'volume_weighted_average': 131.0212,
#   'time': datetime.datetime(2023, 1, 9, 19, 45, tzinfo=<UTC>)},
#  {'open_price': 130.95,
#   'close_price': 131.0837,
#   'high_price': 131.16,
#   'low_price': 130.91,
#   'number_of_trades': 4794,
#   'volume': 484270,
#   'volume_weighted_average': 131.0388,
#   'time': datetime.datetime(2023, 1, 9, 19, 50, tzinfo=<UTC>)},
#  {'open_price': 131.085,
#   'close_price': 130.67,
#   'high_price': 131.09,
#   'low_price': 130.59,
#   'number_of_trades': 6397,
#   'volume': 612447,
#   'volume_weighted_average': 130.8554,
#   'time': datetime.datetime(2023, 1, 9, 19, 55, tzinfo=<UTC>)},
#  {'open_price': 130.68,
#   'close_price': 130.711,
#   'high_price': 130.7711,
#   'low_price': 130.59,
#   'number_of_trades': 5251,
#   'volume': 524010,
#   'volume_weighted_average': 130.6816,
#   'time': datetime.datetime(2023, 1, 9, 20, 0, tzinfo=<UTC>)},
#  {'open_price': 130.72,
#   'close_price': 130.7,
#   'high_price': 130.82,
#   'low_price': 130.515,
#   'number_of_trades': 5618,
#   'volume': 608877,
#   'volume_weighted_average': 130.6897,
#   'time': datetime.datetime(2023, 1, 9, 20, 5, tzinfo=<UTC>)},
#  {'open_price': 130.6914,
#   'close_price': 130.37,
#   'high_price': 130.7375,
#   'low_price': 130.36,
#   'number_of_trades': 6515,
#   'volume': 618950,
#   'volume_weighted_average': 130.5338,
#   'time': datetime.datetime(2023, 1, 9, 20, 10, tzinfo=<UTC>)},
#  {'open_price': 130.3661,
#   'close_price': 130.495,
#   'high_price': 130.55,
#   'low_price': 130.34,
#   'number_of_trades': 5547,
#   'volume': 613609,
#   'volume_weighted_average': 130.4566,
#   'time': datetime.datetime(2023, 1, 9, 20, 15, tzinfo=<UTC>)},
#  {'open_price': 130.5,
#   'close_price': 130.5435,
#   'high_price': 130.7,
#   'low_price': 130.47,
#   'number_of_trades': 5456,
#   'volume': 639601,
#   'volume_weighted_average': 130.6136,
#   'time': datetime.datetime(2023, 1, 9, 20, 20, tzinfo=<UTC>)},
#  {'open_price': 130.54,
#   'close_price': 130.445,
#   'high_price': 130.5799,
#   'low_price': 130.391,
#   'number_of_trades': 5059,
#   'volume': 520094,
#   'volume_weighted_average': 130.5008,
#   'time': datetime.datetime(2023, 1, 9, 20, 25, tzinfo=<UTC>)},
#  {'open_price': 130.45,
#   'close_price': 130.37,
#   'high_price': 130.495,
#   'low_price': 130.16,
#   'number_of_trades': 7579,
#   'volume': 835978,
#   'volume_weighted_average': 130.3385,
#   'time': datetime.datetime(2023, 1, 9, 20, 30, tzinfo=<UTC>)},
#  {'open_price': 130.37,
#   'close_price': 130.275,
#   'high_price': 130.655,
#   'low_price': 130.2518,
#   'number_of_trades': 5416,
#   'volume': 516256,
#   'volume_weighted_average': 130.3527,
#   'time': datetime.datetime(2023, 1, 9, 20, 35, tzinfo=<UTC>)},
#  {'open_price': 130.28,
#   'close_price': 130.5,
#   'high_price': 130.57,
#   'low_price': 130.21,
#   'number_of_trades': 6546,
#   'volume': 665106,
#   'volume_weighted_average': 130.4154,
#   'time': datetime.datetime(2023, 1, 9, 20, 40, tzinfo=<UTC>)},
#  {'open_price': 130.51,
#   'close_price': 130.17,
#   'high_price': 130.52,
#   'low_price': 130.04,
#   'number_of_trades': 7983,
#   'volume': 851529,
#   'volume_weighted_average': 130.2296,
#   'time': datetime.datetime(2023, 1, 9, 20, 45, tzinfo=<UTC>)},
#  {'open_price': 130.18,
#   'close_price': 130.21,
#   'high_price': 130.3299,
#   'low_price': 130.01,
#   'number_of_trades': 10839,
#   'volume': 1117228.0,
#   'volume_weighted_average': 130.1799,
#   'time': datetime.datetime(2023, 1, 9, 20, 50, tzinfo=<UTC>)},
#  {'open_price': 130.215,
#   'close_price': 130.19,
#   'high_price': 130.22,
#   'low_price': 129.89,
#   'number_of_trades': 19549,
#   'volume': 2129822.0,
#   'volume_weighted_average': 130.083,
#   'time': datetime.datetime(2023, 1, 9, 20, 55, tzinfo=<UTC>)},
#  {'open_price': 130.18,
#   'close_price': 130.06,
#   'high_price': 130.18,
#   'low_price': 130.04,
#   'number_of_trades': 428,
#   'volume': 1904376.0,
#   'volume_weighted_average': 130.1495,
#   'time': datetime.datetime(2023, 1, 9, 21, 0, tzinfo=<UTC>)},
#  {'open_price': 130.09,
#   'close_price': 130.12,
#   'high_price': 130.12,
#   'low_price': 130.04,
#   'number_of_trades': 217,
#   'volume': 11787,
#   'volume_weighted_average': 130.0942,
#   'time': datetime.datetime(2023, 1, 9, 21, 5, tzinfo=<UTC>)},
#  {'open_price': 130.15,
#   'close_price': 130.15,
#   'high_price': 130.16,
#   'low_price': 130.11,
#   'number_of_trades': 202,
#   'volume': 30707,
#   'volume_weighted_average': 130.1443,
#   'time': datetime.datetime(2023, 1, 9, 21, 10, tzinfo=<UTC>)},
#  {'open_price': 130.14,
#   'close_price': 130.05,
#   'high_price': 131.709,
#   'low_price': 130.05,
#   'number_of_trades': 227,
#   'volume': 53565,
#   'volume_weighted_average': 131.2762,
#   'time': datetime.datetime(2023, 1, 9, 21, 15, tzinfo=<UTC>)},
#  {'open_price': 130.05,
#   'close_price': 130.05,
#   'high_price': 130.09,
#   'low_price': 130.05,
#   'number_of_trades': 106,
#   'volume': 10258,
#   'volume_weighted_average': 130.0691,
#   'time': datetime.datetime(2023, 1, 9, 21, 20, tzinfo=<UTC>)},
#  {'open_price': 130.09,
#   'close_price': 130.06,
#   'high_price': 130.12,
#   'low_price': 130.04,
#   'number_of_trades': 192,
#   'volume': 295816,
#   'volume_weighted_average': 130.1479,
#   'time': datetime.datetime(2023, 1, 9, 21, 25, tzinfo=<UTC>)},
#  {'open_price': 130.09,
#   'close_price': 130.06,
#   'high_price': 130.1,
#   'low_price': 130.04,
#   'number_of_trades': 123,
#   'volume': 8334,
#   'volume_weighted_average': 130.0727,
#   'time': datetime.datetime(2023, 1, 9, 21, 30, tzinfo=<UTC>)},
#  {'open_price': 130.08,
#   'close_price': 130.08,
#   'high_price': 130.15,
#   'low_price': 130.08,
#   'number_of_trades': 134,
#   'volume': 9491,
#   'volume_weighted_average': 130.1172,
#   'time': datetime.datetime(2023, 1, 9, 21, 35, tzinfo=<UTC>)},
#  {'open_price': 130.1,
#   'close_price': 130.0817,
#   'high_price': 130.1,
#   'low_price': 130.0811,
#   'number_of_trades': 57,
#   'volume': 888,
#   'volume_weighted_average': 130.0954,
#   'time': datetime.datetime(2023, 1, 9, 21, 40, tzinfo=<UTC>)},
#  {'open_price': 130.11,
#   'close_price': 130.11,
#   'high_price': 130.11,
#   'low_price': 130.11,
#   'number_of_trades': 26,
#   'volume': 1794,
#   'volume_weighted_average': 130.1129,
#   'time': datetime.datetime(2023, 1, 9, 21, 45, tzinfo=<UTC>)},
#  {'open_price': 130.13,
#   'close_price': 130.13,
#   'high_price': 130.14,
#   'low_price': 130.12,
#   'number_of_trades': 125,
#   'volume': 2271,
#   'volume_weighted_average': 130.1333,
#   'time': datetime.datetime(2023, 1, 9, 21, 50, tzinfo=<UTC>)},
#  {'open_price': 130.1,
#   'close_price': 130.1,
#   'high_price': 130.1,
#   'low_price': 130.1,
#   'number_of_trades': 31,
#   'volume': 646,
#   'volume_weighted_average': 130.1034,
#   'time': datetime.datetime(2023, 1, 9, 21, 55, tzinfo=<UTC>)},
#  {'open_price': 130.12,
#   'close_price': 130.08,
#   'high_price': 130.12,
#   'low_price': 130.08,
#   'number_of_trades': 57,
#   'volume': 2074,
#   'volume_weighted_average': 130.1021,
#   'time': datetime.datetime(2023, 1, 9, 22, 0, tzinfo=<UTC>)},
#  {'open_price': 130.11,
#   'close_price': 130.06,
#   'high_price': 130.11,
#   'low_price': 130.03,
#   'number_of_trades': 71,
#   'volume': 4037,
#   'volume_weighted_average': 130.0632,
#   'time': datetime.datetime(2023, 1, 9, 22, 10, tzinfo=<UTC>)},
#  {'open_price': 130.06,
#   'close_price': 130.07,
#   'high_price': 130.07,
#   'low_price': 130.0499,
#   'number_of_trades': 46,
#   'volume': 5034,
#   'volume_weighted_average': 130.0537,
#   'time': datetime.datetime(2023, 1, 9, 22, 15, tzinfo=<UTC>)},
#  {'open_price': 130.05,
#   'close_price': 130.04,
#   'high_price': 130.07,
#   'low_price': 130.04,
#   'number_of_trades': 63,
#   'volume': 4241,
#   'volume_weighted_average': 130.0513,
#   'time': datetime.datetime(2023, 1, 9, 22, 20, tzinfo=<UTC>)},
#  {'open_price': 130.09,
#   'close_price': 130.07,
#   'high_price': 130.09,
#   'low_price': 130.0315,
#   'number_of_trades': 100,
#   'volume': 4669,
#   'volume_weighted_average': 130.0512,
#   'time': datetime.datetime(2023, 1, 9, 22, 25, tzinfo=<UTC>)},
#  {'open_price': 130.04,
#   'close_price': 130.06,
#   'high_price': 130.08,
#   'low_price': 130.04,
#   'number_of_trades': 66,
#   'volume': 1050,
#   'volume_weighted_average': 130.0559,
#   'time': datetime.datetime(2023, 1, 9, 22, 30, tzinfo=<UTC>)},
#  {'open_price': 130.0699,
#   'close_price': 130.0699,
#   'high_price': 130.0699,
#   'low_price': 130.0699,
#   'number_of_trades': 22,
#   'volume': 202,
#   'volume_weighted_average': 130.0574,
#   'time': datetime.datetime(2023, 1, 9, 22, 35, tzinfo=<UTC>)},
#  {'open_price': 130.04,
#   'close_price': 130.06,
#   'high_price': 130.06,
#   'low_price': 130.03,
#   'number_of_trades': 60,
#   'volume': 3472,
#   'volume_weighted_average': 130.0413,
#   'time': datetime.datetime(2023, 1, 9, 22, 40, tzinfo=<UTC>)},
#  {'open_price': 130.06,
#   'close_price': 130.05,
#   'high_price': 130.06,
#   'low_price': 130.04,
#   'number_of_trades': 64,
#   'volume': 745,
#   'volume_weighted_average': 130.055,
#   'time': datetime.datetime(2023, 1, 9, 22, 45, tzinfo=<UTC>)},
#  {'open_price': 130.04,
#   'close_price': 130.04,
#   'high_price': 130.04,
#   'low_price': 130.04,
#   'number_of_trades': 108,
#   'volume': 3670,
#   'volume_weighted_average': 130.0402,
#   'time': datetime.datetime(2023, 1, 9, 22, 50, tzinfo=<UTC>)},
#  {'open_price': 130.05,
#   'close_price': 130.04,
#   'high_price': 130.05,
#   'low_price': 130.04,
#   'number_of_trades': 151,
#   'volume': 701,
#   'volume_weighted_average': 130.0476,
#   'time': datetime.datetime(2023, 1, 9, 22, 55, tzinfo=<UTC>)},
#  {'open_price': 130.05,
#   'close_price': 130.01,
#   'high_price': 130.07,
#   'low_price': 130.01,
#   'number_of_trades': 88,
#   'volume': 5160,
#   'volume_weighted_average': 130.0448,
#   'time': datetime.datetime(2023, 1, 9, 23, 0, tzinfo=<UTC>)},
#  {'open_price': 130.01,
#   'close_price': 130.03,
#   'high_price': 130.04,
#   'low_price': 129.95,
#   'number_of_trades': 249,
#   'volume': 32487,
#   'volume_weighted_average': 130.0131,
#   'time': datetime.datetime(2023, 1, 9, 23, 5, tzinfo=<UTC>)},
#  {'open_price': 130.02,
#   'close_price': 129.99,
#   'high_price': 130.05,
#   'low_price': 129.99,
#   'number_of_trades': 201,
#   'volume': 4883,
#   'volume_weighted_average': 130.0157,
#   'time': datetime.datetime(2023, 1, 9, 23, 10, tzinfo=<UTC>)},
#  {'open_price': 130,
#   'close_price': 129.97,
#   'high_price': 130,
#   'low_price': 129.97,
#   'number_of_trades': 132,
#   'volume': 1094,
#   'volume_weighted_average': 129.9886,
#   'time': datetime.datetime(2023, 1, 9, 23, 15, tzinfo=<UTC>)},
#  {'open_price': 129.96,
#   'close_price': 130,
#   'high_price': 130,
#   'low_price': 129.96,
#   'number_of_trades': 77,
#   'volume': 2605,
#   'volume_weighted_average': 129.9845,
#   'time': datetime.datetime(2023, 1, 9, 23, 20, tzinfo=<UTC>)},
#  {'open_price': 130.06,
#   'close_price': 130.06,
#   'high_price': 130.06,
#   'low_price': 130.06,
#   'number_of_trades': 14,
#   'volume': 353,
#   'volume_weighted_average': 130.0502,
#   'time': datetime.datetime(2023, 1, 9, 23, 25, tzinfo=<UTC>)},
#  {'open_price': 130.05,
#   'close_price': 130.05,
#   'high_price': 130.05,
#   'low_price': 130,
#   'number_of_trades': 58,
#   'volume': 2056,
#   'volume_weighted_average': 130.0483,
#   'time': datetime.datetime(2023, 1, 9, 23, 30, tzinfo=<UTC>)},
#  {'open_price': 130.05,
#   'close_price': 130.03,
#   'high_price': 130.05,
#   'low_price': 130.01,
#   'number_of_trades': 56,
#   'volume': 2607,
#   'volume_weighted_average': 130.0316,
#   'time': datetime.datetime(2023, 1, 9, 23, 35, tzinfo=<UTC>)},
#  {'open_price': 130.03,
#   'close_price': 130.03,
#   'high_price': 130.05,
#   'low_price': 130.03,
#   'number_of_trades': 29,
#   'volume': 2600,
#   'volume_weighted_average': 130.0321,
#   'time': datetime.datetime(2023, 1, 9, 23, 40, tzinfo=<UTC>)},
#  {'open_price': 130.03,
#   'close_price': 130.05,
#   'high_price': 130.06,
#   'low_price': 130.02,
#   'number_of_trades': 171,
#   'volume': 5376,
#   'volume_weighted_average': 130.0407,
#   'time': datetime.datetime(2023, 1, 9, 23, 45, tzinfo=<UTC>)},
#  {'open_price': 130.02,
#   'close_price': 130.02,
#   'high_price': 130.03,
#   'low_price': 130.02,
#   'number_of_trades': 35,
#   'volume': 1505,
#   'volume_weighted_average': 130.0245,
#   'time': datetime.datetime(2023, 1, 9, 23, 50, tzinfo=<UTC>)},
#  {'open_price': 130.05,
#   'close_price': 130.04,
#   'high_price': 130.05,
#   'low_price': 130.01,
#   'number_of_trades': 39,
#   'volume': 2357,
#   'volume_weighted_average': 130.0324,
#   'time': datetime.datetime(2023, 1, 9, 23, 55, tzinfo=<UTC>)},
#  {'open_price': 130.01,
#   'close_price': 130.04,
#   'high_price': 130.04,
#   'low_price': 130.01,
#   'number_of_trades': 25,
#   'volume': 1837,
#   'volume_weighted_average': 130.013,
#   'time': datetime.datetime(2023, 1, 10, 0, 0, tzinfo=<UTC>)},
#  {'open_price': 130.02,
#   'close_price': 130,
#   'high_price': 130.04,
#   'low_price': 130,
#   'number_of_trades': 74,
#   'volume': 2867,
#   'volume_weighted_average': 130.0048,
#   'time': datetime.datetime(2023, 1, 10, 0, 5, tzinfo=<UTC>)},
#  {'open_price': 130.03,
#   'close_price': 129.99,
#   'high_price': 130.03,
#   'low_price': 129.99,
#   'number_of_trades': 80,
#   'volume': 5517,
#   'volume_weighted_average': 130.0048,
#   'time': datetime.datetime(2023, 1, 10, 0, 10, tzinfo=<UTC>)},
#  {'open_price': 129.99,
#   'close_price': 129.93,
#   'high_price': 130,
#   'low_price': 129.88,
#   'number_of_trades': 250,
#   'volume': 29416,
#   'volume_weighted_average': 129.9689,
#   'time': datetime.datetime(2023, 1, 10, 0, 15, tzinfo=<UTC>)},
#  {'open_price': 129.93,
#   'close_price': 129.86,
#   'high_price': 129.94,
#   'low_price': 129.85,
#   'number_of_trades': 151,
#   'volume': 7200,
#   'volume_weighted_average': 129.9012,
#   'time': datetime.datetime(2023, 1, 10, 0, 20, tzinfo=<UTC>)},
#  {'open_price': 129.82,
#   'close_price': 129.8,
#   'high_price': 129.82,
#   'low_price': 129.77,
#   'number_of_trades': 148,
#   'volume': 6768,
#   'volume_weighted_average': 129.7942,
#   'time': datetime.datetime(2023, 1, 10, 0, 25, tzinfo=<UTC>)},
#  {'open_price': 129.78,
#   'close_price': 129.81,
#   'high_price': 129.83,
#   'low_price': 129.78,
#   'number_of_trades': 99,
#   'volume': 7985,
#   'volume_weighted_average': 129.7948,
#   'time': datetime.datetime(2023, 1, 10, 0, 30, tzinfo=<UTC>)},
#  {'open_price': 129.8,
#   'close_price': 129.81,
#   'high_price': 129.84,
#   'low_price': 129.8,
#   'number_of_trades': 67,
#   'volume': 4083,
#   'volume_weighted_average': 129.8113,
#   'time': datetime.datetime(2023, 1, 10, 0, 35, tzinfo=<UTC>)},
#  {'open_price': 129.79,
#   'close_price': 129.77,
#   'high_price': 129.79,
#   'low_price': 129.77,
#   'number_of_trades': 78,
#   'volume': 2491,
#   'volume_weighted_average': 129.7813,
#   'time': datetime.datetime(2023, 1, 10, 0, 40, tzinfo=<UTC>)},
#  {'open_price': 129.76,
#   'close_price': 129.78,
#   'high_price': 129.8,
#   'low_price': 129.76,
#   'number_of_trades': 90,
#   'volume': 5680,
#   'volume_weighted_average': 129.7766,
#   'time': datetime.datetime(2023, 1, 10, 0, 45, tzinfo=<UTC>)},
#  {'open_price': 129.8,
#   'close_price': 129.8,
#   'high_price': 129.81,
#   'low_price': 129.77,
#   'number_of_trades': 91,
#   'volume': 6861,
#   'volume_weighted_average': 129.7961,
#   'time': datetime.datetime(2023, 1, 10, 0, 50, tzinfo=<UTC>)},
#  {'open_price': 129.81,
#   'close_price': 129.85,
#   'high_price': 129.85,
#   'low_price': 129.8,
#   'number_of_trades': 155,
#   'volume': 6374,
#   'volume_weighted_average': 129.817,
#   'time': datetime.datetime(2023, 1, 10, 0, 55, tzinfo=<UTC>)}]
