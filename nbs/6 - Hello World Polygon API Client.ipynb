# %%
from decouple import config, AutoConfig

# %%
config = AutoConfig(search_path='.')

# %%
assert config("ALPHA_VANTAGE_API_KEY", default=None, cast=str) is not None

# %%
assert config("POLYGON_API_KEY", default=None, cast=str) is not None

# %%
POLYGON_API_KEY = config("POLYGON_API_KEY", default=None, cast=str)

# %%
POLYGON_API_KEY
# Out:
# 'XAd_OX3sZJ_1b7Cyy3D7WCpuZI2y84Oa'

# %%
import requests

# %%
ticker = "AAPL"
multiplier = "5"
timespan = "minute"
from_date = "2023-01-09"
to_date = "2023-01-09"
path = f"/v2/aggs/ticker/{ticker}/range/{multiplier}/{timespan}/{from_date}/{to_date}"
url = f"https://api.polygon.io{path}?apiKey={POLYGON_API_KEY}"

# %%
import pytz
from typing import Literal
from datetime import datetime
from dataclasses import dataclass
from urllib.parse import urlencode

POLYGON_API_KEY = config("POLYGON_API_KEY", default=None, cast=str)

def transform_polygon_result(result):
    unix_timestamp = result.get('t') / 1000.0
    utc_timestamp = datetime.fromtimestamp(unix_timestamp, tz=pytz.timezone('UTC'))
    return {
        'open_price': result['o'],
        'close_price': result['c'],
        'high_price': result['h'],
        'low_price': result['l'],
        'number_of_trades': result['n'],
        'volume': result['v'],
        'volume_weighted_average': result['vw'],
        'time': utc_timestamp,
    }

@dataclass
class PolygonAPIClient:
    ticker:str = "AAPL"
    multiplier:int = "5"
    timespan:str = "minute"
    from_date:str = "2023-01-09"
    to_date:str = "2023-01-09"
    api_key:str = ""
    adjusted:bool = True
    sort: Literal["asc", "desc"] = "asc"

    def get_params(self):
        return {
            "adjusted": self.adjusted,
            "sort": self.sort,
        }

    def get_api_key(self):
        api_key = self.api_key or POLYGON_API_KEY
        return api_key
    
    def get_headers(self):
        api_key = self.get_api_key()
        
        return {
            "Authorization": f"Bearer {api_key}",
        }
    
    def generate_url(self, pass_auth=False):
        path = f"/v2/aggs/ticker/{self.ticker}/range/{self.multiplier}/{self.timespan}/{self.from_date}/{self.to_date}"
        url = f"https://api.polygon.io{path}"
        if pass_auth:
            api_key = self.get_api_key()
            url += f"&api_key={api_key}"
        params = self.get_params()
        encoded_params = urlencode(params)
        url = f"{url}?{encoded_params}"
        return url

    def fetch_data(self):
        headers = self.get_headers()
        url = self.generate_url()
        response = requests.get(url, headers=headers)
        response.raise_for_status() #not 200/201 status response
        return response.json()

    def get_stock_data(self):
        data = self.fetch_data()
        results = data['results']
        dataset = []
        for result in results:
            dataset.append(
                transform_polygon_result(result)
            )
        return dataset

# %%
PolygonAPIClient(ticker="GOOG", multiplier=1).generate_url(pass_auth=False)
# Out:
# 'https://api.polygon.io/v2/aggs/ticker/GOOG/range/1/minute/2023-01-09/2023-01-09?adjusted=True&sort=asc'

# %%
stock_api_client = PolygonAPIClient(ticker="GOOG", multiplier=1)
dataset = stock_api_client.get_stock_data()
dataset
# Out:
# [{'open_price': 88.08,
#   'close_price': 88.16,
#   'high_price': 88.17,
#   'low_price': 88.08,
#   'number_of_trades': 55,
#   'volume': 1684,
#   'volume_weighted_average': 88.1217,
#   'time': datetime.datetime(2023, 1, 9, 9, 0, tzinfo=<UTC>)},
#  {'open_price': 88.37,
#   'close_price': 88.37,
#   'high_price': 88.37,
#   'low_price': 88.37,
#   'number_of_trades': 12,
#   'volume': 360,
#   'volume_weighted_average': 88.3648,
#   'time': datetime.datetime(2023, 1, 9, 9, 2, tzinfo=<UTC>)},
#  {'open_price': 88.52,
#   'close_price': 88.55,
#   'high_price': 88.55,
#   'low_price': 88.52,
#   'number_of_trades': 32,
#   'volume': 1209,
#   'volume_weighted_average': 88.5577,
#   'time': datetime.datetime(2023, 1, 9, 9, 5, tzinfo=<UTC>)},
#  {'open_price': 88.55,
#   'close_price': 88.55,
#   'high_price': 88.55,
#   'low_price': 88.55,
#   'number_of_trades': 14,
#   'volume': 2169,
#   'volume_weighted_average': 88.548,
#   'time': datetime.datetime(2023, 1, 9, 9, 6, tzinfo=<UTC>)},
#  {'open_price': 88.42,
#   'close_price': 88.42,
#   'high_price': 88.42,
#   'low_price': 88.42,
#   'number_of_trades': 5,
#   'volume': 152,
#   'volume_weighted_average': 88.4496,
#   'time': datetime.datetime(2023, 1, 9, 9, 7, tzinfo=<UTC>)},
#  {'open_price': 88.35,
#   'close_price': 88.35,
#   'high_price': 88.35,
#   'low_price': 88.35,
#   'number_of_trades': 5,
#   'volume': 168,
#   'volume_weighted_average': 88.3512,
#   'time': datetime.datetime(2023, 1, 9, 9, 8, tzinfo=<UTC>)},
#  {'open_price': 88.35,
#   'close_price': 88.35,
#   'high_price': 88.35,
#   'low_price': 88.35,
#   'number_of_trades': 4,
#   'volume': 219,
#   'volume_weighted_average': 88.3498,
#   'time': datetime.datetime(2023, 1, 9, 9, 10, tzinfo=<UTC>)},
#  {'open_price': 88.45,
#   'close_price': 88.45,
#   'high_price': 88.45,
#   'low_price': 88.45,
#   'number_of_trades': 20,
#   'volume': 814,
#   'volume_weighted_average': 88.4404,
#   'time': datetime.datetime(2023, 1, 9, 9, 15, tzinfo=<UTC>)},
#  {'open_price': 88.6,
#   'close_price': 88.61,
#   'high_price': 88.65,
#   'low_price': 88.6,
#   'number_of_trades': 13,
#   'volume': 644,
#   'volume_weighted_average': 88.6165,
#   'time': datetime.datetime(2023, 1, 9, 9, 20, tzinfo=<UTC>)},
#  {'open_price': 88.65,
#   'close_price': 88.65,
#   'high_price': 88.65,
#   'low_price': 88.65,
#   'number_of_trades': 9,
#   'volume': 330,
#   'volume_weighted_average': 88.6494,
#   'time': datetime.datetime(2023, 1, 9, 9, 21, tzinfo=<UTC>)},
#  {'open_price': 88.64,
#   'close_price': 88.64,
#   'high_price': 88.64,
#   'low_price': 88.64,
#   'number_of_trades': 14,
#   'volume': 355,
#   'volume_weighted_average': 88.6348,
#   'time': datetime.datetime(2023, 1, 9, 9, 25, tzinfo=<UTC>)},
#  {'open_price': 88.65,
#   'close_price': 88.65,
#   'high_price': 88.65,
#   'low_price': 88.65,
#   'number_of_trades': 3,
#   'volume': 198,
#   'volume_weighted_average': 88.65,
#   'time': datetime.datetime(2023, 1, 9, 9, 27, tzinfo=<UTC>)},
#  {'open_price': 88.55,
#   'close_price': 88.55,
#   'high_price': 88.55,
#   'low_price': 88.55,
#   'number_of_trades': 5,
#   'volume': 516,
#   'volume_weighted_average': 88.5522,
#   'time': datetime.datetime(2023, 1, 9, 9, 30, tzinfo=<UTC>)},
#  {'open_price': 88.69,
#   'close_price': 88.69,
#   'high_price': 88.69,
#   'low_price': 88.69,
#   'number_of_trades': 3,
#   'volume': 118,
#   'volume_weighted_average': 88.69,
#   'time': datetime.datetime(2023, 1, 9, 9, 39, tzinfo=<UTC>)},
#  {'open_price': 88.66,
#   'close_price': 88.72,
#   'high_price': 88.72,
#   'low_price': 88.66,
#   'number_of_trades': 20,
#   'volume': 1901,
#   'volume_weighted_average': 88.6733,
#   'time': datetime.datetime(2023, 1, 9, 9, 40, tzinfo=<UTC>)},
#  {'open_price': 88.65,
#   'close_price': 88.65,
#   'high_price': 88.65,
#   'low_price': 88.65,
#   'number_of_trades': 6,
#   'volume': 588,
#   'volume_weighted_average': 88.6527,
#   'time': datetime.datetime(2023, 1, 9, 9, 52, tzinfo=<UTC>)},
#  {'open_price': 88.58,
#   'close_price': 88.58,
#   'high_price': 88.58,
#   'low_price': 88.58,
#   'number_of_trades': 27,
#   'volume': 700,
#   'volume_weighted_average': 88.584,
#   'time': datetime.datetime(2023, 1, 9, 9, 58, tzinfo=<UTC>)},
#  {'open_price': 88.55,
#   'close_price': 88.55,
#   'high_price': 88.55,
#   'low_price': 88.55,
#   'number_of_trades': 11,
#   'volume': 351,
#   'volume_weighted_average': 88.55,
#   'time': datetime.datetime(2023, 1, 9, 10, 7, tzinfo=<UTC>)},
#  {'open_price': 88.53,
#   'close_price': 88.53,
#   'high_price': 88.53,
#   'low_price': 88.53,
#   'number_of_trades': 3,
#   'volume': 337,
#   'volume_weighted_average': 88.528,
#   'time': datetime.datetime(2023, 1, 9, 10, 11, tzinfo=<UTC>)},
#  {'open_price': 88.62,
#   'close_price': 88.58,
#   'high_price': 88.62,
#   'low_price': 88.58,
#   'number_of_trades': 11,
#   'volume': 405,
#   'volume_weighted_average': 88.5949,
#   'time': datetime.datetime(2023, 1, 9, 10, 28, tzinfo=<UTC>)},
#  {'open_price': 88.58,
#   'close_price': 88.58,
#   'high_price': 88.58,
#   'low_price': 88.58,
#   'number_of_trades': 4,
#   'volume': 250,
#   'volume_weighted_average': 88.5774,
#   'time': datetime.datetime(2023, 1, 9, 10, 29, tzinfo=<UTC>)},
#  {'open_price': 88.49,
#   'close_price': 88.49,
#   'high_price': 88.49,
#   'low_price': 88.49,
#   'number_of_trades': 9,
#   'volume': 355,
#   'volume_weighted_average': 88.4888,
#   'time': datetime.datetime(2023, 1, 9, 10, 35, tzinfo=<UTC>)},
#  {'open_price': 88.49,
#   'close_price': 88.49,
#   'high_price': 88.49,
#   'low_price': 88.49,
#   'number_of_trades': 3,
#   'volume': 300,
#   'volume_weighted_average': 88.49,
#   'time': datetime.datetime(2023, 1, 9, 10, 36, tzinfo=<UTC>)},
#  {'open_price': 88.49,
#   'close_price': 88.49,
#   'high_price': 88.49,
#   'low_price': 88.49,
#   'number_of_trades': 1,
#   'volume': 100,
#   'volume_weighted_average': 88.49,
#   'time': datetime.datetime(2023, 1, 9, 10, 37, tzinfo=<UTC>)},
#  {'open_price': 88.45,
#   'close_price': 88.45,
#   'high_price': 88.45,
#   'low_price': 88.45,
#   'number_of_trades': 4,
#   'volume': 308,
#   'volume_weighted_average': 88.4511,
#   'time': datetime.datetime(2023, 1, 9, 10, 45, tzinfo=<UTC>)},
#  {'open_price': 88.42,
#   'close_price': 88.42,
#   'high_price': 88.42,
#   'low_price': 88.42,
#   'number_of_trades': 9,
#   'volume': 531,
#   'volume_weighted_average': 88.4208,
#   'time': datetime.datetime(2023, 1, 9, 10, 49, tzinfo=<UTC>)},
#  {'open_price': 88.42,
#   'close_price': 88.37,
#   'high_price': 88.42,
#   'low_price': 88.37,
#   'number_of_trades': 21,
#   'volume': 1127,
#   'volume_weighted_average': 88.3779,
#   'time': datetime.datetime(2023, 1, 9, 10, 59, tzinfo=<UTC>)},
#  {'open_price': 88.49,
#   'close_price': 88.49,
#   'high_price': 88.49,
#   'low_price': 88.49,
#   'number_of_trades': 6,
#   'volume': 201,
#   'volume_weighted_average': 88.4766,
#   'time': datetime.datetime(2023, 1, 9, 11, 0, tzinfo=<UTC>)},
#  {'open_price': 88.45,
#   'close_price': 88.45,
#   'high_price': 88.45,
#   'low_price': 88.45,
#   'number_of_trades': 5,
#   'volume': 146,
#   'volume_weighted_average': 88.4193,
#   'time': datetime.datetime(2023, 1, 9, 11, 6, tzinfo=<UTC>)},
#  {'open_price': 88.4,
#   'close_price': 88.4,
#   'high_price': 88.4,
#   'low_price': 88.4,
#   'number_of_trades': 1,
#   'volume': 100,
#   'volume_weighted_average': 88.4,
#   'time': datetime.datetime(2023, 1, 9, 11, 11, tzinfo=<UTC>)},
#  {'open_price': 88.43,
#   'close_price': 88.42,
#   'high_price': 88.43,
#   'low_price': 88.42,
#   'number_of_trades': 3,
#   'volume': 201,
#   'volume_weighted_average': 88.425,
#   'time': datetime.datetime(2023, 1, 9, 11, 15, tzinfo=<UTC>)},
#  {'open_price': 88.45,
#   'close_price': 88.45,
#   'high_price': 88.45,
#   'low_price': 88.45,
#   'number_of_trades': 2,
#   'volume': 101,
#   'volume_weighted_average': 88.45,
#   'time': datetime.datetime(2023, 1, 9, 11, 17, tzinfo=<UTC>)},
#  {'open_price': 88.4,
#   'close_price': 88.4,
#   'high_price': 88.4,
#   'low_price': 88.4,
#   'number_of_trades': 5,
#   'volume': 500,
#   'volume_weighted_average': 88.4,
#   'time': datetime.datetime(2023, 1, 9, 11, 34, tzinfo=<UTC>)},
#  {'open_price': 88.36,
#   'close_price': 88.36,
#   'high_price': 88.36,
#   'low_price': 88.36,
#   'number_of_trades': 9,
#   'volume': 191,
#   'volume_weighted_average': 88.3569,
#   'time': datetime.datetime(2023, 1, 9, 11, 43, tzinfo=<UTC>)},
#  {'open_price': 88.4,
#   'close_price': 88.4,
#   'high_price': 88.4,
#   'low_price': 88.4,
#   'number_of_trades': 2,
#   'volume': 121,
#   'volume_weighted_average': 88.4,
#   'time': datetime.datetime(2023, 1, 9, 11, 46, tzinfo=<UTC>)},
#  {'open_price': 88.39,
#   'close_price': 88.38,
#   'high_price': 88.39,
#   'low_price': 88.38,
#   'number_of_trades': 88,
#   'volume': 3540,
#   'volume_weighted_average': 88.3926,
#   'time': datetime.datetime(2023, 1, 9, 12, 0, tzinfo=<UTC>)},
#  {'open_price': 88.42,
#   'close_price': 88.42,
#   'high_price': 88.42,
#   'low_price': 88.42,
#   'number_of_trades': 18,
#   'volume': 400,
#   'volume_weighted_average': 88.42,
#   'time': datetime.datetime(2023, 1, 9, 12, 3, tzinfo=<UTC>)},
#  {'open_price': 88.49,
#   'close_price': 88.5,
#   'high_price': 88.5,
#   'low_price': 88.49,
#   'number_of_trades': 24,
#   'volume': 2830,
#   'volume_weighted_average': 88.4937,
#   'time': datetime.datetime(2023, 1, 9, 12, 7, tzinfo=<UTC>)},
#  {'open_price': 88.5,
#   'close_price': 88.5,
#   'high_price': 88.5,
#   'low_price': 88.5,
#   'number_of_trades': 14,
#   'volume': 970,
#   'volume_weighted_average': 88.5012,
#   'time': datetime.datetime(2023, 1, 9, 12, 8, tzinfo=<UTC>)},
#  {'open_price': 88.5,
#   'close_price': 88.5,
#   'high_price': 88.5,
#   'low_price': 88.5,
#   'number_of_trades': 7,
#   'volume': 811,
#   'volume_weighted_average': 88.5017,
#   'time': datetime.datetime(2023, 1, 9, 12, 9, tzinfo=<UTC>)},
#  {'open_price': 88.54,
#   'close_price': 88.55,
#   'high_price': 88.55,
#   'low_price': 88.54,
#   'number_of_trades': 11,
#   'volume': 562,
#   'volume_weighted_average': 88.5421,
#   'time': datetime.datetime(2023, 1, 9, 12, 13, tzinfo=<UTC>)},
#  {'open_price': 88.5,
#   'close_price': 88.5,
#   'high_price': 88.5,
#   'low_price': 88.5,
#   'number_of_trades': 22,
#   'volume': 1800,
#   'volume_weighted_average': 88.5095,
#   'time': datetime.datetime(2023, 1, 9, 12, 15, tzinfo=<UTC>)},
#  {'open_price': 88.55,
#   'close_price': 88.55,
#   'high_price': 88.55,
#   'low_price': 88.55,
#   'number_of_trades': 6,
#   'volume': 290,
#   'volume_weighted_average': 88.5441,
#   'time': datetime.datetime(2023, 1, 9, 12, 18, tzinfo=<UTC>)},
#  {'open_price': 88.54,
#   'close_price': 88.54,
#   'high_price': 88.54,
#   'low_price': 88.54,
#   'number_of_trades': 21,
#   'volume': 687,
#   'volume_weighted_average': 88.5411,
#   'time': datetime.datetime(2023, 1, 9, 12, 19, tzinfo=<UTC>)},
#  {'open_price': 88.55,
#   'close_price': 88.55,
#   'high_price': 88.55,
#   'low_price': 88.55,
#   'number_of_trades': 10,
#   'volume': 794,
#   'volume_weighted_average': 88.5511,
#   'time': datetime.datetime(2023, 1, 9, 12, 21, tzinfo=<UTC>)},
#  {'open_price': 88.55,
#   'close_price': 88.55,
#   'high_price': 88.55,
#   'low_price': 88.55,
#   'number_of_trades': 3,
#   'volume': 766,
#   'volume_weighted_average': 88.55,
#   'time': datetime.datetime(2023, 1, 9, 12, 22, tzinfo=<UTC>)},
#  {'open_price': 88.55,
#   'close_price': 88.55,
#   'high_price': 88.55,
#   'low_price': 88.55,
#   'number_of_trades': 8,
#   'volume': 518,
#   'volume_weighted_average': 88.55,
#   'time': datetime.datetime(2023, 1, 9, 12, 23, tzinfo=<UTC>)},
#  {'open_price': 88.52,
#   'close_price': 88.52,
#   'high_price': 88.52,
#   'low_price': 88.52,
#   'number_of_trades': 13,
#   'volume': 430,
#   'volume_weighted_average': 88.5272,
#   'time': datetime.datetime(2023, 1, 9, 12, 24, tzinfo=<UTC>)},
#  {'open_price': 88.55,
#   'close_price': 88.55,
#   'high_price': 88.55,
#   'low_price': 88.55,
#   'number_of_trades': 15,
#   'volume': 234,
#   'volume_weighted_average': 88.5498,
#   'time': datetime.datetime(2023, 1, 9, 12, 25, tzinfo=<UTC>)},
#  {'open_price': 88.63,
#   'close_price': 88.63,
#   'high_price': 88.63,
#   'low_price': 88.63,
#   'number_of_trades': 13,
#   'volume': 415,
#   'volume_weighted_average': 88.6138,
#   'time': datetime.datetime(2023, 1, 9, 12, 32, tzinfo=<UTC>)},
#  {'open_price': 88.78,
#   'close_price': 88.78,
#   'high_price': 88.78,
#   'low_price': 88.78,
#   'number_of_trades': 2,
#   'volume': 105,
#   'volume_weighted_average': 88.779,
#   'time': datetime.datetime(2023, 1, 9, 12, 37, tzinfo=<UTC>)},
#  {'open_price': 88.8,
#   'close_price': 88.8,
#   'high_price': 88.8,
#   'low_price': 88.8,
#   'number_of_trades': 15,
#   'volume': 223,
#   'volume_weighted_average': 88.7974,
#   'time': datetime.datetime(2023, 1, 9, 12, 38, tzinfo=<UTC>)},
#  {'open_price': 88.8,
#   'close_price': 88.8,
#   'high_price': 88.8,
#   'low_price': 88.8,
#   'number_of_trades': 11,
#   'volume': 209,
#   'volume_weighted_average': 88.8022,
#   'time': datetime.datetime(2023, 1, 9, 12, 39, tzinfo=<UTC>)},
#  {'open_price': 88.75,
#   'close_price': 88.75,
#   'high_price': 88.75,
#   'low_price': 88.75,
#   'number_of_trades': 12,
#   'volume': 306,
#   'volume_weighted_average': 88.7463,
#   'time': datetime.datetime(2023, 1, 9, 12, 45, tzinfo=<UTC>)},
#  {'open_price': 88.7,
#   'close_price': 88.7,
#   'high_price': 88.7,
#   'low_price': 88.7,
#   'number_of_trades': 11,
#   'volume': 403,
#   'volume_weighted_average': 88.71,
#   'time': datetime.datetime(2023, 1, 9, 12, 50, tzinfo=<UTC>)},
#  {'open_price': 88.77,
#   'close_price': 88.77,
#   'high_price': 88.77,
#   'low_price': 88.77,
#   'number_of_trades': 21,
#   'volume': 999,
#   'volume_weighted_average': 88.7592,
#   'time': datetime.datetime(2023, 1, 9, 12, 51, tzinfo=<UTC>)},
#  {'open_price': 88.75,
#   'close_price': 88.75,
#   'high_price': 88.75,
#   'low_price': 88.75,
#   'number_of_trades': 4,
#   'volume': 190,
#   'volume_weighted_average': 88.75,
#   'time': datetime.datetime(2023, 1, 9, 12, 57, tzinfo=<UTC>)},
#  {'open_price': 88.36,
#   'close_price': 88.3315,
#   'high_price': 88.85,
#   'low_price': 88.3315,
#   'number_of_trades': 145,
#   'volume': 11469,
#   'volume_weighted_average': 88.6048,
#   'time': datetime.datetime(2023, 1, 9, 13, 0, tzinfo=<UTC>)},
#  {'open_price': 88.34,
#   'close_price': 88.34,
#   'high_price': 88.34,
#   'low_price': 88.34,
#   'number_of_trades': 30,
#   'volume': 554,
#   'volume_weighted_average': 88.4368,
#   'time': datetime.datetime(2023, 1, 9, 13, 1, tzinfo=<UTC>)},
#  {'open_price': 88.74,
#   'close_price': 88.7,
#   'high_price': 88.74,
#   'low_price': 88.7,
#   'number_of_trades': 72,
#   'volume': 2232,
#   'volume_weighted_average': 88.7128,
#   'time': datetime.datetime(2023, 1, 9, 13, 4, tzinfo=<UTC>)},
#  {'open_price': 88.64,
#   'close_price': 88.59,
#   'high_price': 88.64,
#   'low_price': 88.59,
#   'number_of_trades': 32,
#   'volume': 2741,
#   'volume_weighted_average': 88.6071,
#   'time': datetime.datetime(2023, 1, 9, 13, 5, tzinfo=<UTC>)},
#  {'open_price': 88.5613,
#   'close_price': 88.52,
#   'high_price': 88.5613,
#   'low_price': 88.52,
#   'number_of_trades': 45,
#   'volume': 2173,
#   'volume_weighted_average': 88.5305,
#   'time': datetime.datetime(2023, 1, 9, 13, 7, tzinfo=<UTC>)},
#  {'open_price': 88.52,
#   'close_price': 88.52,
#   'high_price': 88.52,
#   'low_price': 88.52,
#   'number_of_trades': 15,
#   'volume': 460,
#   'volume_weighted_average': 88.5241,
#   'time': datetime.datetime(2023, 1, 9, 13, 8, tzinfo=<UTC>)},
#  {'open_price': 88.53,
#   'close_price': 88.6384,
#   'high_price': 88.6384,
#   'low_price': 88.53,
#   'number_of_trades': 9,
#   'volume': 1125,
#   'volume_weighted_average': 88.5757,
#   'time': datetime.datetime(2023, 1, 9, 13, 10, tzinfo=<UTC>)},
#  {'open_price': 88.5249,
#   'close_price': 88.5249,
#   'high_price': 88.5249,
#   'low_price': 88.5249,
#   'number_of_trades': 5,
#   'volume': 275,
#   'volume_weighted_average': 88.5442,
#   'time': datetime.datetime(2023, 1, 9, 13, 11, tzinfo=<UTC>)},
#  {'open_price': 88.62,
#   'close_price': 88.6453,
#   'high_price': 88.6453,
#   'low_price': 88.62,
#   'number_of_trades': 27,
#   'volume': 1095,
#   'volume_weighted_average': 88.6132,
#   'time': datetime.datetime(2023, 1, 9, 13, 15, tzinfo=<UTC>)},
#  {'open_price': 88.7185,
#   'close_price': 88.6202,
#   'high_price': 88.7185,
#   'low_price': 88.6202,
#   'number_of_trades': 8,
#   'volume': 1095,
#   'volume_weighted_average': 88.6597,
#   'time': datetime.datetime(2023, 1, 9, 13, 18, tzinfo=<UTC>)},
#  {'open_price': 88.79,
#   'close_price': 88.79,
#   'high_price': 88.79,
#   'low_price': 88.79,
#   'number_of_trades': 2,
#   'volume': 501,
#   'volume_weighted_average': 88.79,
#   'time': datetime.datetime(2023, 1, 9, 13, 26, tzinfo=<UTC>)},
#  {'open_price': 88.75,
#   'close_price': 88.75,
#   'high_price': 88.75,
#   'low_price': 88.75,
#   'number_of_trades': 4,
#   'volume': 109,
#   'volume_weighted_average': 88.7489,
#   'time': datetime.datetime(2023, 1, 9, 13, 28, tzinfo=<UTC>)},
#  {'open_price': 88.8,
#   'close_price': 88.64,
#   'high_price': 88.8,
#   'low_price': 88.64,
#   'number_of_trades': 17,
#   'volume': 589,
#   'volume_weighted_average': 88.7405,
#   'time': datetime.datetime(2023, 1, 9, 13, 29, tzinfo=<UTC>)},
#  {'open_price': 88.78,
#   'close_price': 88.8,
#   'high_price': 88.8,
#   'low_price': 88.78,
#   'number_of_trades': 22,
#   'volume': 987,
#   'volume_weighted_average': 88.7944,
#   'time': datetime.datetime(2023, 1, 9, 13, 31, tzinfo=<UTC>)},
#  {'open_price': 88.85,
#   'close_price': 88.86,
#   'high_price': 88.86,
#   'low_price': 88.8,
#   'number_of_trades': 7,
#   'volume': 927,
#   'volume_weighted_average': 88.8347,
#   'time': datetime.datetime(2023, 1, 9, 13, 32, tzinfo=<UTC>)},
#  {'open_price': 88.87,
#   'close_price': 88.87,
#   'high_price': 88.87,
#   'low_price': 88.87,
#   'number_of_trades': 10,
#   'volume': 152,
#   'volume_weighted_average': 88.8666,
#   'time': datetime.datetime(2023, 1, 9, 13, 34, tzinfo=<UTC>)},
#  {'open_price': 88.9,
#   'close_price': 88.9,
#   'high_price': 88.9,
#   'low_price': 88.9,
#   'number_of_trades': 27,
#   'volume': 1024,
#   'volume_weighted_average': 88.8941,
#   'time': datetime.datetime(2023, 1, 9, 13, 36, tzinfo=<UTC>)},
#  {'open_price': 88.9,
#   'close_price': 88.87,
#   'high_price': 88.93,
#   'low_price': 88.87,
#   'number_of_trades': 56,
#   'volume': 2877,
#   'volume_weighted_average': 88.8945,
#   'time': datetime.datetime(2023, 1, 9, 13, 37, tzinfo=<UTC>)},
#  {'open_price': 88.85,
#   'close_price': 88.85,
#   'high_price': 88.85,
#   'low_price': 88.85,
#   'number_of_trades': 25,
#   'volume': 485,
#   'volume_weighted_average': 88.8763,
#   'time': datetime.datetime(2023, 1, 9, 13, 38, tzinfo=<UTC>)},
#  {'open_price': 88.81,
#   'close_price': 88.79,
#   'high_price': 88.81,
#   'low_price': 88.79,
#   'number_of_trades': 54,
#   'volume': 1769,
#   'volume_weighted_average': 88.8151,
#   'time': datetime.datetime(2023, 1, 9, 13, 40, tzinfo=<UTC>)},
#  {'open_price': 88.8481,
#   'close_price': 88.8481,
#   'high_price': 88.8481,
#   'low_price': 88.8481,
#   'number_of_trades': 7,
#   'volume': 318,
#   'volume_weighted_average': 88.8365,
#   'time': datetime.datetime(2023, 1, 9, 13, 41, tzinfo=<UTC>)},
#  {'open_price': 88.8896,
#   'close_price': 88.8896,
#   'high_price': 88.8896,
#   'low_price': 88.8896,
#   'number_of_trades': 9,
#   'volume': 171,
#   'volume_weighted_average': 88.8747,
#   'time': datetime.datetime(2023, 1, 9, 13, 42, tzinfo=<UTC>)},
#  {'open_price': 88.78,
#   'close_price': 88.78,
#   'high_price': 88.78,
#   'low_price': 88.78,
#   'number_of_trades': 10,
#   'volume': 710,
#   'volume_weighted_average': 88.7891,
#   'time': datetime.datetime(2023, 1, 9, 13, 44, tzinfo=<UTC>)},
#  {'open_price': 88.9,
#   'close_price': 88.95,
#   'high_price': 88.95,
#   'low_price': 88.9,
#   'number_of_trades': 29,
#   'volume': 1188,
#   'volume_weighted_average': 88.9283,
#   'time': datetime.datetime(2023, 1, 9, 13, 48, tzinfo=<UTC>)},
#  {'open_price': 88.9499,
#   'close_price': 88.9499,
#   'high_price': 88.9499,
#   'low_price': 88.9499,
#   'number_of_trades': 13,
#   'volume': 312,
#   'volume_weighted_average': 88.925,
#   'time': datetime.datetime(2023, 1, 9, 13, 49, tzinfo=<UTC>)},
#  {'open_price': 88.88,
#   'close_price': 88.9,
#   'high_price': 88.9,
#   'low_price': 88.88,
#   'number_of_trades': 17,
#   'volume': 1250,
#   'volume_weighted_average': 88.8886,
#   'time': datetime.datetime(2023, 1, 9, 13, 50, tzinfo=<UTC>)},
#  {'open_price': 88.95,
#   'close_price': 88.95,
#   'high_price': 88.95,
#   'low_price': 88.95,
#   'number_of_trades': 28,
#   'volume': 784,
#   'volume_weighted_average': 88.9552,
#   'time': datetime.datetime(2023, 1, 9, 13, 55, tzinfo=<UTC>)},
#  {'open_price': 88.87,
#   'close_price': 88.87,
#   'high_price': 88.87,
#   'low_price': 88.87,
#   'number_of_trades': 63,
#   'volume': 1968,
#   'volume_weighted_average': 88.8994,
#   'time': datetime.datetime(2023, 1, 9, 13, 56, tzinfo=<UTC>)},
#  {'open_price': 88.87,
#   'close_price': 88.87,
#   'high_price': 88.87,
#   'low_price': 88.87,
#   'number_of_trades': 35,
#   'volume': 752,
#   'volume_weighted_average': 88.8532,
#   'time': datetime.datetime(2023, 1, 9, 13, 57, tzinfo=<UTC>)},
#  {'open_price': 88.9,
#   'close_price': 88.9,
#   'high_price': 88.9,
#   'low_price': 88.9,
#   'number_of_trades': 24,
#   'volume': 764,
#   'volume_weighted_average': 88.825,
#   'time': datetime.datetime(2023, 1, 9, 13, 58, tzinfo=<UTC>)},
#  {'open_price': 88.81,
#   'close_price': 88.81,
#   'high_price': 88.81,
#   'low_price': 88.81,
#   'number_of_trades': 10,
#   'volume': 551,
#   'volume_weighted_average': 88.8131,
#   'time': datetime.datetime(2023, 1, 9, 13, 59, tzinfo=<UTC>)},
#  {'open_price': 88.78,
#   'close_price': 88.84,
#   'high_price': 88.84,
#   'low_price': 88.78,
#   'number_of_trades': 75,
#   'volume': 2698,
#   'volume_weighted_average': 88.8054,
#   'time': datetime.datetime(2023, 1, 9, 14, 0, tzinfo=<UTC>)},
#  {'open_price': 88.7,
#   'close_price': 88.7,
#   'high_price': 88.7,
#   'low_price': 88.7,
#   'number_of_trades': 22,
#   'volume': 589,
#   'volume_weighted_average': 88.714,
#   'time': datetime.datetime(2023, 1, 9, 14, 1, tzinfo=<UTC>)},
#  {'open_price': 88.6812,
#   'close_price': 88.6812,
#   'high_price': 88.6812,
#   'low_price': 88.6812,
#   'number_of_trades': 19,
#   'volume': 674,
#   'volume_weighted_average': 88.7152,
#   'time': datetime.datetime(2023, 1, 9, 14, 2, tzinfo=<UTC>)},
#  {'open_price': 88.72,
#   'close_price': 88.72,
#   'high_price': 88.72,
#   'low_price': 88.72,
#   'number_of_trades': 44,
#   'volume': 1525,
#   'volume_weighted_average': 88.7509,
#   'time': datetime.datetime(2023, 1, 9, 14, 6, tzinfo=<UTC>)},
#  {'open_price': 88.8,
#   'close_price': 88.8,
#   'high_price': 88.8,
#   'low_price': 88.8,
#   'number_of_trades': 6,
#   'volume': 114,
#   'volume_weighted_average': 88.8002,
#   'time': datetime.datetime(2023, 1, 9, 14, 7, tzinfo=<UTC>)},
#  {'open_price': 88.85,
#   'close_price': 88.86,
#   'high_price': 88.86,
#   'low_price': 88.85,
#   'number_of_trades': 30,
#   'volume': 1063,
#   'volume_weighted_average': 88.8454,
#   'time': datetime.datetime(2023, 1, 9, 14, 9, tzinfo=<UTC>)},
#  {'open_price': 88.86,
#   'close_price': 88.86,
#   'high_price': 88.86,
#   'low_price': 88.86,
#   'number_of_trades': 24,
#   'volume': 516,
#   'volume_weighted_average': 88.8288,
#   'time': datetime.datetime(2023, 1, 9, 14, 12, tzinfo=<UTC>)},
#  {'open_price': 88.8499,
#   'close_price': 88.8499,
#   'high_price': 88.8499,
#   'low_price': 88.8499,
#   'number_of_trades': 15,
#   'volume': 192,
#   'volume_weighted_average': 88.8288,
#   'time': datetime.datetime(2023, 1, 9, 14, 13, tzinfo=<UTC>)},
#  {'open_price': 88.84,
#   'close_price': 88.84,
#   'high_price': 88.84,
#   'low_price': 88.84,
#   'number_of_trades': 10,
#   'volume': 280,
#   'volume_weighted_average': 88.7838,
#   'time': datetime.datetime(2023, 1, 9, 14, 14, tzinfo=<UTC>)},
#  {'open_price': 88.8,
#   'close_price': 88.8,
#   'high_price': 88.8,
#   'low_price': 88.8,
#   'number_of_trades': 9,
#   'volume': 419,
#   'volume_weighted_average': 88.806,
#   'time': datetime.datetime(2023, 1, 9, 14, 18, tzinfo=<UTC>)},
#  {'open_price': 88.83,
#   'close_price': 88.87,
#   'high_price': 88.87,
#   'low_price': 88.83,
#   'number_of_trades': 15,
#   'volume': 1052,
#   'volume_weighted_average': 88.8548,
#   'time': datetime.datetime(2023, 1, 9, 14, 19, tzinfo=<UTC>)},
#  {'open_price': 88.87,
#   'close_price': 88.87,
#   'high_price': 88.87,
#   'low_price': 88.87,
#   'number_of_trades': 19,
#   'volume': 417,
#   'volume_weighted_average': 88.8602,
#   'time': datetime.datetime(2023, 1, 9, 14, 20, tzinfo=<UTC>)},
#  {'open_price': 88.89,
#   'close_price': 88.89,
#   'high_price': 88.89,
#   'low_price': 88.89,
#   'number_of_trades': 44,
#   'volume': 1241,
#   'volume_weighted_average': 88.8656,
#   'time': datetime.datetime(2023, 1, 9, 14, 21, tzinfo=<UTC>)},
#  {'open_price': 88.92,
#   'close_price': 88.96,
#   'high_price': 88.98,
#   'low_price': 88.92,
#   'number_of_trades': 49,
#   'volume': 2531,
#   'volume_weighted_average': 88.9552,
#   'time': datetime.datetime(2023, 1, 9, 14, 22, tzinfo=<UTC>)},
#  {'open_price': 89.02,
#   'close_price': 89.02,
#   'high_price': 89.02,
#   'low_price': 89.02,
#   'number_of_trades': 107,
#   'volume': 5045,
#   'volume_weighted_average': 89.0359,
#   'time': datetime.datetime(2023, 1, 9, 14, 23, tzinfo=<UTC>)},
#  {'open_price': 89.15,
#   'close_price': 89.14,
#   'high_price': 89.15,
#   'low_price': 89.12,
#   'number_of_trades': 46,
#   'volume': 3729,
#   'volume_weighted_average': 89.1462,
#   'time': datetime.datetime(2023, 1, 9, 14, 24, tzinfo=<UTC>)},
#  {'open_price': 89.12,
#   'close_price': 89.15,
#   'high_price': 89.15,
#   'low_price': 89.12,
#   'number_of_trades': 31,
#   'volume': 825,
#   'volume_weighted_average': 89.1094,
#   'time': datetime.datetime(2023, 1, 9, 14, 25, tzinfo=<UTC>)},
#  {'open_price': 89.05,
#   'close_price': 89.05,
#   'high_price': 89.05,
#   'low_price': 89.05,
#   'number_of_trades': 9,
#   'volume': 226,
#   'volume_weighted_average': 89.0467,
#   'time': datetime.datetime(2023, 1, 9, 14, 26, tzinfo=<UTC>)},
#  {'open_price': 89.17,
#   'close_price': 89.2,
#   'high_price': 89.2,
#   'low_price': 89.17,
#   'number_of_trades': 61,
#   'volume': 2945,
#   'volume_weighted_average': 89.185,
#   'time': datetime.datetime(2023, 1, 9, 14, 27, tzinfo=<UTC>)},
#  {'open_price': 89.18,
#   'close_price': 89.11,
#   'high_price': 89.18,
#   'low_price': 89.05,
#   'number_of_trades': 58,
#   'volume': 2840,
#   'volume_weighted_average': 89.0762,
#   'time': datetime.datetime(2023, 1, 9, 14, 28, tzinfo=<UTC>)},
#  {'open_price': 89.06,
#   'close_price': 89.17,
#   'high_price': 89.17,
#   'low_price': 89,
#   'number_of_trades': 61,
#   'volume': 3562,
#   'volume_weighted_average': 89.089,
#   'time': datetime.datetime(2023, 1, 9, 14, 29, tzinfo=<UTC>)},
#  {'open_price': 89.195,
#   'close_price': 88.98,
#   'high_price': 89.44,
#   'low_price': 88.96,
#   'number_of_trades': 3399,
#   'volume': 501765,
#   'volume_weighted_average': 89.1577,
#   'time': datetime.datetime(2023, 1, 9, 14, 30, tzinfo=<UTC>)},
#  {'open_price': 88.99,
#   'close_price': 89.475,
#   'high_price': 89.48,
#   'low_price': 88.95,
#   'number_of_trades': 2232,
#   'volume': 192305,
#   'volume_weighted_average': 89.1522,
#   'time': datetime.datetime(2023, 1, 9, 14, 31, tzinfo=<UTC>)},
#  {'open_price': 89.5,
#   'close_price': 89.515,
#   'high_price': 89.61,
#   'low_price': 89.3253,
#   'number_of_trades': 1255,
#   'volume': 112483,
#   'volume_weighted_average': 89.4906,
#   'time': datetime.datetime(2023, 1, 9, 14, 32, tzinfo=<UTC>)},
#  {'open_price': 89.53,
#   'close_price': 89.4213,
#   'high_price': 89.57,
#   'low_price': 89.4,
#   'number_of_trades': 1022,
#   'volume': 68804,
#   'volume_weighted_average': 89.5167,
#   'time': datetime.datetime(2023, 1, 9, 14, 33, tzinfo=<UTC>)},
#  {'open_price': 89.428,
#   'close_price': 89.47,
#   'high_price': 89.51,
#   'low_price': 89.23,
#   'number_of_trades': 1231,
#   'volume': 111013,
#   'volume_weighted_average': 89.3535,
#   'time': datetime.datetime(2023, 1, 9, 14, 34, tzinfo=<UTC>)},
#  {'open_price': 89.46,
#   'close_price': 89.69,
#   'high_price': 89.7,
#   'low_price': 89.46,
#   'number_of_trades': 1138,
#   'volume': 88734,
#   'volume_weighted_average': 89.5467,
#   'time': datetime.datetime(2023, 1, 9, 14, 35, tzinfo=<UTC>)},
#  {'open_price': 89.69,
#   'close_price': 89.17,
#   'high_price': 89.71,
#   'low_price': 89.155,
#   'number_of_trades': 1963,
#   'volume': 185918,
#   'volume_weighted_average': 89.4249,
#   'time': datetime.datetime(2023, 1, 9, 14, 36, tzinfo=<UTC>)},
#  {'open_price': 89.17,
#   'close_price': 89.38,
#   'high_price': 89.43,
#   'low_price': 89.072,
#   'number_of_trades': 1360,
#   'volume': 132229,
#   'volume_weighted_average': 89.2354,
#   'time': datetime.datetime(2023, 1, 9, 14, 37, tzinfo=<UTC>)},
#  {'open_price': 89.37,
#   'close_price': 89.32,
#   'high_price': 89.49,
#   'low_price': 89.31,
#   'number_of_trades': 1087,
#   'volume': 87446,
#   'volume_weighted_average': 89.4039,
#   'time': datetime.datetime(2023, 1, 9, 14, 38, tzinfo=<UTC>)},
#  {'open_price': 89.32,
#   'close_price': 89.585,
#   'high_price': 89.62,
#   'low_price': 89.27,
#   'number_of_trades': 1156,
#   'volume': 81795,
#   'volume_weighted_average': 89.4157,
#   'time': datetime.datetime(2023, 1, 9, 14, 39, tzinfo=<UTC>)},
#  {'open_price': 89.58,
#   'close_price': 89.48,
#   'high_price': 89.615,
#   'low_price': 89.43,
#   'number_of_trades': 929,
#   'volume': 60919,
#   'volume_weighted_average': 89.5078,
#   'time': datetime.datetime(2023, 1, 9, 14, 40, tzinfo=<UTC>)},
#  {'open_price': 89.48,
#   'close_price': 89.41,
#   'high_price': 89.54,
#   'low_price': 89.36,
#   'number_of_trades': 901,
#   'volume': 87788,
#   'volume_weighted_average': 89.4243,
#   'time': datetime.datetime(2023, 1, 9, 14, 41, tzinfo=<UTC>)},
#  {'open_price': 89.4,
#   'close_price': 89.09,
#   'high_price': 89.4,
#   'low_price': 89.005,
#   'number_of_trades': 1457,
#   'volume': 137150,
#   'volume_weighted_average': 89.2027,
#   'time': datetime.datetime(2023, 1, 9, 14, 42, tzinfo=<UTC>)},
#  {'open_price': 89.08,
#   'close_price': 89.44,
#   'high_price': 89.46,
#   'low_price': 89.08,
#   'number_of_trades': 655,
#   'volume': 52166,
#   'volume_weighted_average': 89.3039,
#   'time': datetime.datetime(2023, 1, 9, 14, 43, tzinfo=<UTC>)},
#  {'open_price': 89.46,
#   'close_price': 89.64,
#   'high_price': 89.65,
#   'low_price': 89.44,
#   'number_of_trades': 725,
#   'volume': 60590,
#   'volume_weighted_average': 89.5704,
#   'time': datetime.datetime(2023, 1, 9, 14, 44, tzinfo=<UTC>)},
#  {'open_price': 89.65,
#   'close_price': 89.75,
#   'high_price': 89.76,
#   'low_price': 89.62,
#   'number_of_trades': 997,
#   'volume': 60488,
#   'volume_weighted_average': 89.6988,
#   'time': datetime.datetime(2023, 1, 9, 14, 45, tzinfo=<UTC>)},
#  {'open_price': 89.75,
#   'close_price': 89.86,
#   'high_price': 89.88,
#   'low_price': 89.72,
#   'number_of_trades': 1080,
#   'volume': 120473,
#   'volume_weighted_average': 89.7845,
#   'time': datetime.datetime(2023, 1, 9, 14, 46, tzinfo=<UTC>)},
#  {'open_price': 89.86,
#   'close_price': 89.7065,
#   'high_price': 89.86,
#   'low_price': 89.675,
#   'number_of_trades': 786,
#   'volume': 62670,
#   'volume_weighted_average': 89.7504,
#   'time': datetime.datetime(2023, 1, 9, 14, 47, tzinfo=<UTC>)},
#  {'open_price': 89.71,
#   'close_price': 89.8,
#   'high_price': 89.83,
#   'low_price': 89.7,
#   'number_of_trades': 932,
#   'volume': 61063,
#   'volume_weighted_average': 89.7612,
#   'time': datetime.datetime(2023, 1, 9, 14, 48, tzinfo=<UTC>)},
#  {'open_price': 89.81,
#   'close_price': 89.8199,
#   'high_price': 89.84,
#   'low_price': 89.727,
#   'number_of_trades': 738,
#   'volume': 73069,
#   'volume_weighted_average': 89.7896,
#   'time': datetime.datetime(2023, 1, 9, 14, 49, tzinfo=<UTC>)},
#  {'open_price': 89.81,
#   'close_price': 89.8399,
#   'high_price': 89.87,
#   'low_price': 89.78,
#   'number_of_trades': 709,
#   'volume': 44854,
#   'volume_weighted_average': 89.8288,
#   'time': datetime.datetime(2023, 1, 9, 14, 50, tzinfo=<UTC>)},
#  {'open_price': 89.83,
#   'close_price': 89.81,
#   'high_price': 89.85,
#   'low_price': 89.759,
#   'number_of_trades': 826,
#   'volume': 54264,
#   'volume_weighted_average': 89.8085,
#   'time': datetime.datetime(2023, 1, 9, 14, 51, tzinfo=<UTC>)},
#  {'open_price': 89.81,
#   'close_price': 89.95,
#   'high_price': 89.99,
#   'low_price': 89.81,
#   'number_of_trades': 925,
#   'volume': 72950,
#   'volume_weighted_average': 89.9253,
#   'time': datetime.datetime(2023, 1, 9, 14, 52, tzinfo=<UTC>)},
#  {'open_price': 89.95,
#   'close_price': 89.89,
#   'high_price': 90.07,
#   'low_price': 89.87,
#   'number_of_trades': 1226,
#   'volume': 136605,
#   'volume_weighted_average': 89.9822,
#   'time': datetime.datetime(2023, 1, 9, 14, 53, tzinfo=<UTC>)},
#  {'open_price': 89.89,
#   'close_price': 89.865,
#   'high_price': 89.9,
#   'low_price': 89.75,
#   'number_of_trades': 811,
#   'volume': 53489,
#   'volume_weighted_average': 89.8247,
#   'time': datetime.datetime(2023, 1, 9, 14, 54, tzinfo=<UTC>)},
#  {'open_price': 89.87,
#   'close_price': 89.78,
#   'high_price': 89.875,
#   'low_price': 89.72,
#   'number_of_trades': 965,
#   'volume': 70214,
#   'volume_weighted_average': 89.778,
#   'time': datetime.datetime(2023, 1, 9, 14, 55, tzinfo=<UTC>)},
#  {'open_price': 89.7993,
#   'close_price': 89.76,
#   'high_price': 89.84,
#   'low_price': 89.675,
#   'number_of_trades': 974,
#   'volume': 87740,
#   'volume_weighted_average': 89.7476,
#   'time': datetime.datetime(2023, 1, 9, 14, 56, tzinfo=<UTC>)},
#  {'open_price': 89.76,
#   'close_price': 89.85,
#   'high_price': 89.85,
#   'low_price': 89.75,
#   'number_of_trades': 518,
#   'volume': 38449,
#   'volume_weighted_average': 89.8128,
#   'time': datetime.datetime(2023, 1, 9, 14, 57, tzinfo=<UTC>)},
#  {'open_price': 89.84,
#   'close_price': 89.84,
#   'high_price': 89.91,
#   'low_price': 89.77,
#   'number_of_trades': 937,
#   'volume': 78053,
#   'volume_weighted_average': 89.844,
#   'time': datetime.datetime(2023, 1, 9, 14, 58, tzinfo=<UTC>)},
#  {'open_price': 89.8477,
#   'close_price': 89.915,
#   'high_price': 89.96,
#   'low_price': 89.84,
#   'number_of_trades': 642,
#   'volume': 41585,
#   'volume_weighted_average': 89.9051,
#   'time': datetime.datetime(2023, 1, 9, 14, 59, tzinfo=<UTC>)},
#  {'open_price': 89.92,
#   'close_price': 90.0018,
#   'high_price': 90.04,
#   'low_price': 89.91,
#   'number_of_trades': 1028,
#   'volume': 109551,
#   'volume_weighted_average': 89.9962,
#   'time': datetime.datetime(2023, 1, 9, 15, 0, tzinfo=<UTC>)},
#  {'open_price': 90,
#   'close_price': 89.86,
#   'high_price': 90.04,
#   'low_price': 89.85,
#   'number_of_trades': 943,
#   'volume': 56554,
#   'volume_weighted_average': 89.9633,
#   'time': datetime.datetime(2023, 1, 9, 15, 1, tzinfo=<UTC>)},
#  {'open_price': 89.8603,
#   'close_price': 89.9435,
#   'high_price': 89.95,
#   'low_price': 89.845,
#   'number_of_trades': 947,
#   'volume': 63160,
#   'volume_weighted_average': 89.9024,
#   'time': datetime.datetime(2023, 1, 9, 15, 2, tzinfo=<UTC>)},
#  {'open_price': 89.94,
#   'close_price': 90.04,
#   'high_price': 90.0409,
#   'low_price': 89.87,
#   'number_of_trades': 886,
#   'volume': 61226,
#   'volume_weighted_average': 89.9694,
#   'time': datetime.datetime(2023, 1, 9, 15, 3, tzinfo=<UTC>)},
#  {'open_price': 90.04,
#   'close_price': 90.1,
#   'high_price': 90.11,
#   'low_price': 90.02,
#   'number_of_trades': 858,
#   'volume': 75296,
#   'volume_weighted_average': 90.0698,
#   'time': datetime.datetime(2023, 1, 9, 15, 4, tzinfo=<UTC>)},
#  {'open_price': 90.1088,
#   'close_price': 90,
#   'high_price': 90.1096,
#   'low_price': 89.95,
#   'number_of_trades': 894,
#   'volume': 73458,
#   'volume_weighted_average': 90.0199,
#   'time': datetime.datetime(2023, 1, 9, 15, 5, tzinfo=<UTC>)},
#  {'open_price': 89.981,
#   'close_price': 89.9845,
#   'high_price': 90.01,
#   'low_price': 89.95,
#   'number_of_trades': 560,
#   'volume': 32498,
#   'volume_weighted_average': 89.9842,
#   'time': datetime.datetime(2023, 1, 9, 15, 6, tzinfo=<UTC>)},
#  {'open_price': 90,
#   'close_price': 89.99,
#   'high_price': 90.025,
#   'low_price': 89.96,
#   'number_of_trades': 988,
#   'volume': 66742,
#   'volume_weighted_average': 89.9994,
#   'time': datetime.datetime(2023, 1, 9, 15, 7, tzinfo=<UTC>)},
#  {'open_price': 90,
#   'close_price': 90.0746,
#   'high_price': 90.13,
#   'low_price': 89.97,
#   'number_of_trades': 645,
#   'volume': 103163,
#   'volume_weighted_average': 90.0272,
#   'time': datetime.datetime(2023, 1, 9, 15, 8, tzinfo=<UTC>)},
#  {'open_price': 90.07,
#   'close_price': 90.16,
#   'high_price': 90.17,
#   'low_price': 90.02,
#   'number_of_trades': 599,
#   'volume': 47721,
#   'volume_weighted_average': 90.113,
#   'time': datetime.datetime(2023, 1, 9, 15, 9, tzinfo=<UTC>)},
#  {'open_price': 90.16,
#   'close_price': 90.19,
#   'high_price': 90.24,
#   'low_price': 90.15,
#   'number_of_trades': 730,
#   'volume': 67081,
#   'volume_weighted_average': 90.1811,
#   'time': datetime.datetime(2023, 1, 9, 15, 10, tzinfo=<UTC>)},
#  {'open_price': 90.18,
#   'close_price': 90.135,
#   'high_price': 90.18,
#   'low_price': 90.093,
#   'number_of_trades': 533,
#   'volume': 47264,
#   'volume_weighted_average': 90.1321,
#   'time': datetime.datetime(2023, 1, 9, 15, 11, tzinfo=<UTC>)},
#  {'open_price': 90.1301,
#   'close_price': 90.055,
#   'high_price': 90.18,
#   'low_price': 90.03,
#   'number_of_trades': 493,
#   'volume': 42715,
#   'volume_weighted_average': 90.0939,
#   'time': datetime.datetime(2023, 1, 9, 15, 12, tzinfo=<UTC>)},
#  {'open_price': 90.06,
#   'close_price': 90.093,
#   'high_price': 90.1,
#   'low_price': 89.9599,
#   'number_of_trades': 644,
#   'volume': 46755,
#   'volume_weighted_average': 90.0323,
#   'time': datetime.datetime(2023, 1, 9, 15, 13, tzinfo=<UTC>)},
#  {'open_price': 90.11,
#   'close_price': 90.06,
#   'high_price': 90.13,
#   'low_price': 90.06,
#   'number_of_trades': 645,
#   'volume': 56147,
#   'volume_weighted_average': 90.0966,
#   'time': datetime.datetime(2023, 1, 9, 15, 14, tzinfo=<UTC>)},
#  {'open_price': 90.06,
#   'close_price': 90.15,
#   'high_price': 90.17,
#   'low_price': 90.055,
#   'number_of_trades': 663,
#   'volume': 53632,
#   'volume_weighted_average': 90.1261,
#   'time': datetime.datetime(2023, 1, 9, 15, 15, tzinfo=<UTC>)},
#  {'open_price': 90.1591,
#   'close_price': 90.1598,
#   'high_price': 90.23,
#   'low_price': 90.13,
#   'number_of_trades': 603,
#   'volume': 44056,
#   'volume_weighted_average': 90.1732,
#   'time': datetime.datetime(2023, 1, 9, 15, 16, tzinfo=<UTC>)},
#  {'open_price': 90.16,
#   'close_price': 90.01,
#   'high_price': 90.2,
#   'low_price': 90.01,
#   'number_of_trades': 786,
#   'volume': 64964,
#   'volume_weighted_average': 90.1461,
#   'time': datetime.datetime(2023, 1, 9, 15, 17, tzinfo=<UTC>)},
#  {'open_price': 90,
#   'close_price': 90.03,
#   'high_price': 90.03,
#   'low_price': 89.94,
#   'number_of_trades': 926,
#   'volume': 73192,
#   'volume_weighted_average': 89.9931,
#   'time': datetime.datetime(2023, 1, 9, 15, 18, tzinfo=<UTC>)},
#  {'open_price': 90.025,
#   'close_price': 90.09,
#   'high_price': 90.1,
#   'low_price': 90.025,
#   'number_of_trades': 783,
#   'volume': 66673,
#   'volume_weighted_average': 90.0621,
#   'time': datetime.datetime(2023, 1, 9, 15, 19, tzinfo=<UTC>)},
#  {'open_price': 90.095,
#   'close_price': 90.11,
#   'high_price': 90.17,
#   'low_price': 90.07,
#   'number_of_trades': 614,
#   'volume': 53845,
#   'volume_weighted_average': 90.1326,
#   'time': datetime.datetime(2023, 1, 9, 15, 20, tzinfo=<UTC>)},
#  {'open_price': 90.11,
#   'close_price': 90.04,
#   'high_price': 90.14,
#   'low_price': 90.01,
#   'number_of_trades': 775,
#   'volume': 70082,
#   'volume_weighted_average': 90.084,
#   'time': datetime.datetime(2023, 1, 9, 15, 21, tzinfo=<UTC>)},
#  {'open_price': 90.035,
#   'close_price': 89.97,
#   'high_price': 90.04,
#   'low_price': 89.955,
#   'number_of_trades': 890,
#   'volume': 81273,
#   'volume_weighted_average': 90.013,
#   'time': datetime.datetime(2023, 1, 9, 15, 22, tzinfo=<UTC>)},
#  {'open_price': 89.97,
#   'close_price': 90.0001,
#   'high_price': 90.04,
#   'low_price': 89.96,
#   'number_of_trades': 696,
#   'volume': 50744,
#   'volume_weighted_average': 90.0096,
#   'time': datetime.datetime(2023, 1, 9, 15, 23, tzinfo=<UTC>)},
#  {'open_price': 90.005,
#   'close_price': 90.03,
#   'high_price': 90.08,
#   'low_price': 90.005,
#   'number_of_trades': 497,
#   'volume': 36414,
#   'volume_weighted_average': 90.0547,
#   'time': datetime.datetime(2023, 1, 9, 15, 24, tzinfo=<UTC>)},
#  {'open_price': 90.03,
#   'close_price': 90,
#   'high_price': 90.05,
#   'low_price': 89.96,
#   'number_of_trades': 454,
#   'volume': 30564,
#   'volume_weighted_average': 90.0136,
#   'time': datetime.datetime(2023, 1, 9, 15, 25, tzinfo=<UTC>)},
#  {'open_price': 90.02,
#   'close_price': 89.99,
#   'high_price': 90.045,
#   'low_price': 89.96,
#   'number_of_trades': 331,
#   'volume': 22178,
#   'volume_weighted_average': 90.0067,
#   'time': datetime.datetime(2023, 1, 9, 15, 26, tzinfo=<UTC>)},
#  {'open_price': 89.98,
#   'close_price': 90.035,
#   'high_price': 90.05,
#   'low_price': 89.96,
#   'number_of_trades': 482,
#   'volume': 32289,
#   'volume_weighted_average': 90.0186,
#   'time': datetime.datetime(2023, 1, 9, 15, 27, tzinfo=<UTC>)},
#  {'open_price': 90.04,
#   'close_price': 90.02,
#   'high_price': 90.06,
#   'low_price': 89.99,
#   'number_of_trades': 384,
#   'volume': 52498,
#   'volume_weighted_average': 90.0215,
#   'time': datetime.datetime(2023, 1, 9, 15, 28, tzinfo=<UTC>)},
#  {'open_price': 90.02,
#   'close_price': 89.9121,
#   'high_price': 90.025,
#   'low_price': 89.905,
#   'number_of_trades': 480,
#   'volume': 42210,
#   'volume_weighted_average': 89.9683,
#   'time': datetime.datetime(2023, 1, 9, 15, 29, tzinfo=<UTC>)},
#  {'open_price': 89.91,
#   'close_price': 89.915,
#   'high_price': 90.05,
#   'low_price': 89.89,
#   'number_of_trades': 575,
#   'volume': 46003,
#   'volume_weighted_average': 89.9556,
#   'time': datetime.datetime(2023, 1, 9, 15, 30, tzinfo=<UTC>)},
#  {'open_price': 89.91,
#   'close_price': 89.93,
#   'high_price': 89.97,
#   'low_price': 89.84,
#   'number_of_trades': 338,
#   'volume': 26597,
#   'volume_weighted_average': 89.9095,
#   'time': datetime.datetime(2023, 1, 9, 15, 31, tzinfo=<UTC>)},
#  {'open_price': 89.92,
#   'close_price': 89.97,
#   'high_price': 89.99,
#   'low_price': 89.87,
#   'number_of_trades': 441,
#   'volume': 37327,
#   'volume_weighted_average': 89.9149,
#   'time': datetime.datetime(2023, 1, 9, 15, 32, tzinfo=<UTC>)},
#  {'open_price': 89.96,
#   'close_price': 90.09,
#   'high_price': 90.09,
#   'low_price': 89.96,
#   'number_of_trades': 614,
#   'volume': 52662,
#   'volume_weighted_average': 90.0288,
#   'time': datetime.datetime(2023, 1, 9, 15, 33, tzinfo=<UTC>)},
#  {'open_price': 90.1,
#   'close_price': 90.1,
#   'high_price': 90.135,
#   'low_price': 90.0781,
#   'number_of_trades': 390,
#   'volume': 34716,
#   'volume_weighted_average': 90.1052,
#   'time': datetime.datetime(2023, 1, 9, 15, 34, tzinfo=<UTC>)},
#  {'open_price': 90.11,
#   'close_price': 90.23,
#   'high_price': 90.24,
#   'low_price': 90.11,
#   'number_of_trades': 897,
#   'volume': 70401,
#   'volume_weighted_average': 90.1865,
#   'time': datetime.datetime(2023, 1, 9, 15, 35, tzinfo=<UTC>)},
#  {'open_price': 90.2498,
#   'close_price': 90.36,
#   'high_price': 90.38,
#   'low_price': 90.2497,
#   'number_of_trades': 674,
#   'volume': 67849,
#   'volume_weighted_average': 90.323,
#   'time': datetime.datetime(2023, 1, 9, 15, 36, tzinfo=<UTC>)},
#  {'open_price': 90.365,
#   'close_price': 90.425,
#   'high_price': 90.485,
#   'low_price': 90.36,
#   'number_of_trades': 615,
#   'volume': 64067,
#   'volume_weighted_average': 90.4272,
#   'time': datetime.datetime(2023, 1, 9, 15, 37, tzinfo=<UTC>)},
#  {'open_price': 90.43,
#   'close_price': 90.4099,
#   'high_price': 90.45,
#   'low_price': 90.38,
#   'number_of_trades': 473,
#   'volume': 37538,
#   'volume_weighted_average': 90.416,
#   'time': datetime.datetime(2023, 1, 9, 15, 38, tzinfo=<UTC>)},
#  {'open_price': 90.41,
#   'close_price': 90.5,
#   'high_price': 90.5,
#   'low_price': 90.4,
#   'number_of_trades': 597,
#   'volume': 68421,
#   'volume_weighted_average': 90.459,
#   'time': datetime.datetime(2023, 1, 9, 15, 39, tzinfo=<UTC>)},
#  {'open_price': 90.5,
#   'close_price': 90.44,
#   'high_price': 90.535,
#   'low_price': 90.42,
#   'number_of_trades': 648,
#   'volume': 93491,
#   'volume_weighted_average': 90.496,
#   'time': datetime.datetime(2023, 1, 9, 15, 40, tzinfo=<UTC>)},
#  {'open_price': 90.43,
#   'close_price': 90.43,
#   'high_price': 90.48,
#   'low_price': 90.4,
#   'number_of_trades': 509,
#   'volume': 54341,
#   'volume_weighted_average': 90.4395,
#   'time': datetime.datetime(2023, 1, 9, 15, 41, tzinfo=<UTC>)},
#  {'open_price': 90.44,
#   'close_price': 90.51,
#   'high_price': 90.51,
#   'low_price': 90.42,
#   'number_of_trades': 388,
#   'volume': 36740,
#   'volume_weighted_average': 90.4491,
#   'time': datetime.datetime(2023, 1, 9, 15, 42, tzinfo=<UTC>)},
#  {'open_price': 90.51,
#   'close_price': 90.47,
#   'high_price': 90.52,
#   'low_price': 90.44,
#   'number_of_trades': 502,
#   'volume': 58769,
#   'volume_weighted_average': 90.4753,
#   'time': datetime.datetime(2023, 1, 9, 15, 43, tzinfo=<UTC>)},
#  {'open_price': 90.475,
#   'close_price': 90.57,
#   'high_price': 90.57,
#   'low_price': 90.44,
#   'number_of_trades': 595,
#   'volume': 72114,
#   'volume_weighted_average': 90.5125,
#   'time': datetime.datetime(2023, 1, 9, 15, 44, tzinfo=<UTC>)},
#  {'open_price': 90.57,
#   'close_price': 90.55,
#   'high_price': 90.6,
#   'low_price': 90.525,
#   'number_of_trades': 596,
#   'volume': 57517,
#   'volume_weighted_average': 90.57,
#   'time': datetime.datetime(2023, 1, 9, 15, 45, tzinfo=<UTC>)},
#  {'open_price': 90.55,
#   'close_price': 90.535,
#   'high_price': 90.61,
#   'low_price': 90.52,
#   'number_of_trades': 736,
#   'volume': 63129,
#   'volume_weighted_average': 90.5631,
#   'time': datetime.datetime(2023, 1, 9, 15, 46, tzinfo=<UTC>)},
#  {'open_price': 90.53,
#   'close_price': 90.53,
#   'high_price': 90.57,
#   'low_price': 90.47,
#   'number_of_trades': 988,
#   'volume': 90978,
#   'volume_weighted_average': 90.5246,
#   'time': datetime.datetime(2023, 1, 9, 15, 47, tzinfo=<UTC>)},
#  {'open_price': 90.53,
#   'close_price': 90.59,
#   'high_price': 90.605,
#   'low_price': 90.515,
#   'number_of_trades': 604,
#   'volume': 53482,
#   'volume_weighted_average': 90.5704,
#   'time': datetime.datetime(2023, 1, 9, 15, 48, tzinfo=<UTC>)},
#  {'open_price': 90.585,
#   'close_price': 90.62,
#   'high_price': 90.64,
#   'low_price': 90.575,
#   'number_of_trades': 869,
#   'volume': 114141,
#   'volume_weighted_average': 90.6056,
#   'time': datetime.datetime(2023, 1, 9, 15, 49, tzinfo=<UTC>)},
#  {'open_price': 90.62,
#   'close_price': 90.56,
#   'high_price': 90.66,
#   'low_price': 90.56,
#   'number_of_trades': 761,
#   'volume': 105331,
#   'volume_weighted_average': 90.6252,
#   'time': datetime.datetime(2023, 1, 9, 15, 50, tzinfo=<UTC>)},
#  {'open_price': 90.56,
#   'close_price': 90.55,
#   'high_price': 90.585,
#   'low_price': 90.52,
#   'number_of_trades': 469,
#   'volume': 63349,
#   'volume_weighted_average': 90.5496,
#   'time': datetime.datetime(2023, 1, 9, 15, 51, tzinfo=<UTC>)},
#  {'open_price': 90.55,
#   'close_price': 90.5024,
#   'high_price': 90.585,
#   'low_price': 90.4935,
#   'number_of_trades': 444,
#   'volume': 37901,
#   'volume_weighted_average': 90.5434,
#   'time': datetime.datetime(2023, 1, 9, 15, 52, tzinfo=<UTC>)},
#  {'open_price': 90.5001,
#   'close_price': 90.5152,
#   'high_price': 90.53,
#   'low_price': 90.475,
#   'number_of_trades': 451,
#   'volume': 42078,
#   'volume_weighted_average': 90.501,
#   'time': datetime.datetime(2023, 1, 9, 15, 53, tzinfo=<UTC>)},
#  {'open_price': 90.51,
#   'close_price': 90.48,
#   'high_price': 90.52,
#   'low_price': 90.44,
#   'number_of_trades': 505,
#   'volume': 39805,
#   'volume_weighted_average': 90.4732,
#   'time': datetime.datetime(2023, 1, 9, 15, 54, tzinfo=<UTC>)},
#  {'open_price': 90.49,
#   'close_price': 90.35,
#   'high_price': 90.49,
#   'low_price': 90.3368,
#   'number_of_trades': 462,
#   'volume': 62896,
#   'volume_weighted_average': 90.4065,
#   'time': datetime.datetime(2023, 1, 9, 15, 55, tzinfo=<UTC>)},
#  {'open_price': 90.355,
#   'close_price': 90.2899,
#   'high_price': 90.37,
#   'low_price': 90.2827,
#   'number_of_trades': 419,
#   'volume': 38839,
#   'volume_weighted_average': 90.3198,
#   'time': datetime.datetime(2023, 1, 9, 15, 56, tzinfo=<UTC>)},
#  {'open_price': 90.288,
#   'close_price': 90.31,
#   'high_price': 90.31,
#   'low_price': 90.24,
#   'number_of_trades': 364,
#   'volume': 35977,
#   'volume_weighted_average': 90.2729,
#   'time': datetime.datetime(2023, 1, 9, 15, 57, tzinfo=<UTC>)},
#  {'open_price': 90.3036,
#   'close_price': 90.21,
#   'high_price': 90.32,
#   'low_price': 90.17,
#   'number_of_trades': 381,
#   'volume': 32394,
#   'volume_weighted_average': 90.26,
#   'time': datetime.datetime(2023, 1, 9, 15, 58, tzinfo=<UTC>)},
#  {'open_price': 90.225,
#   'close_price': 90.19,
#   'high_price': 90.23,
#   'low_price': 90.17,
#   'number_of_trades': 314,
#   'volume': 27820,
#   'volume_weighted_average': 90.2092,
#   'time': datetime.datetime(2023, 1, 9, 15, 59, tzinfo=<UTC>)},
#  {'open_price': 90.2,
#   'close_price': 90.26,
#   'high_price': 90.31,
#   'low_price': 90.19,
#   'number_of_trades': 353,
#   'volume': 40976,
#   'volume_weighted_average': 90.2709,
#   'time': datetime.datetime(2023, 1, 9, 16, 0, tzinfo=<UTC>)},
#  {'open_price': 90.25,
#   'close_price': 90.165,
#   'high_price': 90.25,
#   'low_price': 90.145,
#   'number_of_trades': 497,
#   'volume': 42687,
#   'volume_weighted_average': 90.1768,
#   'time': datetime.datetime(2023, 1, 9, 16, 1, tzinfo=<UTC>)},
#  {'open_price': 90.16,
#   'close_price': 90.17,
#   'high_price': 90.22,
#   'low_price': 90.15,
# ...
#   'high_price': 88.8,
#   'low_price': 88.67,
#   'number_of_trades': 12,
#   'volume': 39536,
#   'volume_weighted_average': 88.7993,
#   'time': datetime.datetime(2023, 1, 9, 21, 1, tzinfo=<UTC>)},
#  {'open_price': 88.71,
#   'close_price': 88.71,
#   'high_price': 88.71,
#   'low_price': 88.71,
#   'number_of_trades': 7,
#   'volume': 184,
#   'volume_weighted_average': 88.7084,
#   'time': datetime.datetime(2023, 1, 9, 21, 2, tzinfo=<UTC>)},
#  {'open_price': 88.68,
#   'close_price': 88.68,
#   'high_price': 88.71,
#   'low_price': 88.68,
#   'number_of_trades': 17,
#   'volume': 921,
#   'volume_weighted_average': 88.6862,
#   'time': datetime.datetime(2023, 1, 9, 21, 3, tzinfo=<UTC>)},
#  {'open_price': 88.73,
#   'close_price': 88.76,
#   'high_price': 88.8,
#   'low_price': 88.73,
#   'number_of_trades': 48,
#   'volume': 2444,
#   'volume_weighted_average': 88.7643,
#   'time': datetime.datetime(2023, 1, 9, 21, 5, tzinfo=<UTC>)},
#  {'open_price': 88.7287,
#   'close_price': 88.7287,
#   'high_price': 88.7287,
#   'low_price': 88.7287,
#   'number_of_trades': 20,
#   'volume': 317,
#   'volume_weighted_average': 88.7167,
#   'time': datetime.datetime(2023, 1, 9, 21, 6, tzinfo=<UTC>)},
#  {'open_price': 88.71,
#   'close_price': 88.73,
#   'high_price': 88.73,
#   'low_price': 88.7,
#   'number_of_trades': 11,
#   'volume': 370,
#   'volume_weighted_average': 88.716,
#   'time': datetime.datetime(2023, 1, 9, 21, 7, tzinfo=<UTC>)},
#  {'open_price': 88.8,
#   'close_price': 88.8,
#   'high_price': 88.8,
#   'low_price': 88.8,
#   'number_of_trades': 3,
#   'volume': 4335,
#   'volume_weighted_average': 88.8,
#   'time': datetime.datetime(2023, 1, 9, 21, 10, tzinfo=<UTC>)},
#  {'open_price': 88.8,
#   'close_price': 88.8,
#   'high_price': 88.8,
#   'low_price': 88.8,
#   'number_of_trades': 5,
#   'volume': 1452,
#   'volume_weighted_average': 88.7945,
#   'time': datetime.datetime(2023, 1, 9, 21, 11, tzinfo=<UTC>)},
#  {'open_price': 88.8,
#   'close_price': 88.74,
#   'high_price': 88.8,
#   'low_price': 88.74,
#   'number_of_trades': 4,
#   'volume': 13298,
#   'volume_weighted_average': 88.7989,
#   'time': datetime.datetime(2023, 1, 9, 21, 12, tzinfo=<UTC>)},
#  {'open_price': 89.6904,
#   'close_price': 88.78,
#   'high_price': 89.6904,
#   'low_price': 88.78,
#   'number_of_trades': 6,
#   'volume': 1240,
#   'volume_weighted_average': 89.5231,
#   'time': datetime.datetime(2023, 1, 9, 21, 14, tzinfo=<UTC>)},
#  {'open_price': 88.71,
#   'close_price': 88.73,
#   'high_price': 88.73,
#   'low_price': 88.71,
#   'number_of_trades': 16,
#   'volume': 410,
#   'volume_weighted_average': 88.7289,
#   'time': datetime.datetime(2023, 1, 9, 21, 15, tzinfo=<UTC>)},
#  {'open_price': 88.7,
#   'close_price': 88.66,
#   'high_price': 88.7,
#   'low_price': 88.66,
#   'number_of_trades': 31,
#   'volume': 693,
#   'volume_weighted_average': 88.6964,
#   'time': datetime.datetime(2023, 1, 9, 21, 17, tzinfo=<UTC>)},
#  {'open_price': 88.68,
#   'close_price': 88.68,
#   'high_price': 88.68,
#   'low_price': 88.68,
#   'number_of_trades': 35,
#   'volume': 870,
#   'volume_weighted_average': 88.6846,
#   'time': datetime.datetime(2023, 1, 9, 21, 18, tzinfo=<UTC>)},
#  {'open_price': 88.71,
#   'close_price': 88.71,
#   'high_price': 88.71,
#   'low_price': 88.71,
#   'number_of_trades': 1,
#   'volume': 100,
#   'volume_weighted_average': 88.71,
#   'time': datetime.datetime(2023, 1, 9, 21, 21, tzinfo=<UTC>)},
#  {'open_price': 88.67,
#   'close_price': 88.59,
#   'high_price': 88.67,
#   'low_price': 88.59,
#   'number_of_trades': 56,
#   'volume': 1734,
#   'volume_weighted_average': 88.6389,
#   'time': datetime.datetime(2023, 1, 9, 21, 22, tzinfo=<UTC>)},
#  {'open_price': 88.65,
#   'close_price': 88.65,
#   'high_price': 88.65,
#   'low_price': 88.65,
#   'number_of_trades': 5,
#   'volume': 2490,
#   'volume_weighted_average': 88.65,
#   'time': datetime.datetime(2023, 1, 9, 21, 24, tzinfo=<UTC>)},
#  {'open_price': 88.69,
#   'close_price': 88.69,
#   'high_price': 88.69,
#   'low_price': 88.69,
#   'number_of_trades': 2,
#   'volume': 102,
#   'volume_weighted_average': 88.6892,
#   'time': datetime.datetime(2023, 1, 9, 21, 26, tzinfo=<UTC>)},
#  {'open_price': 88.72,
#   'close_price': 88.67,
#   'high_price': 88.72,
#   'low_price': 88.67,
#   'number_of_trades': 17,
#   'volume': 428,
#   'volume_weighted_average': 88.6827,
#   'time': datetime.datetime(2023, 1, 9, 21, 30, tzinfo=<UTC>)},
#  {'open_price': 88.68,
#   'close_price': 88.68,
#   'high_price': 88.68,
#   'low_price': 88.68,
#   'number_of_trades': 4,
#   'volume': 121,
#   'volume_weighted_average': 88.6826,
#   'time': datetime.datetime(2023, 1, 9, 21, 31, tzinfo=<UTC>)},
#  {'open_price': 88.74,
#   'close_price': 88.74,
#   'high_price': 88.74,
#   'low_price': 88.74,
#   'number_of_trades': 2,
#   'volume': 201,
#   'volume_weighted_average': 88.7399,
#   'time': datetime.datetime(2023, 1, 9, 21, 33, tzinfo=<UTC>)},
#  {'open_price': 88.74,
#   'close_price': 88.74,
#   'high_price': 88.74,
#   'low_price': 88.74,
#   'number_of_trades': 5,
#   'volume': 148,
#   'volume_weighted_average': 88.7403,
#   'time': datetime.datetime(2023, 1, 9, 21, 34, tzinfo=<UTC>)},
#  {'open_price': 88.74,
#   'close_price': 88.72,
#   'high_price': 88.74,
#   'low_price': 88.72,
#   'number_of_trades': 5,
#   'volume': 227,
#   'volume_weighted_average': 88.7315,
#   'time': datetime.datetime(2023, 1, 9, 21, 35, tzinfo=<UTC>)},
#  {'open_price': 88.74,
#   'close_price': 88.74,
#   'high_price': 88.74,
#   'low_price': 88.74,
#   'number_of_trades': 2,
#   'volume': 160,
#   'volume_weighted_average': 88.7437,
#   'time': datetime.datetime(2023, 1, 9, 21, 38, tzinfo=<UTC>)},
#  {'open_price': 88.75,
#   'close_price': 88.75,
#   'high_price': 88.75,
#   'low_price': 88.75,
#   'number_of_trades': 4,
#   'volume': 233,
#   'volume_weighted_average': 88.7499,
#   'time': datetime.datetime(2023, 1, 9, 21, 39, tzinfo=<UTC>)},
#  {'open_price': 88.7,
#   'close_price': 88.7,
#   'high_price': 88.7,
#   'low_price': 88.7,
#   'number_of_trades': 2,
#   'volume': 101,
#   'volume_weighted_average': 88.7001,
#   'time': datetime.datetime(2023, 1, 9, 21, 45, tzinfo=<UTC>)},
#  {'open_price': 88.73,
#   'close_price': 88.73,
#   'high_price': 88.73,
#   'low_price': 88.73,
#   'number_of_trades': 5,
#   'volume': 562,
#   'volume_weighted_average': 88.7294,
#   'time': datetime.datetime(2023, 1, 9, 21, 46, tzinfo=<UTC>)},
#  {'open_price': 88.74,
#   'close_price': 88.74,
#   'high_price': 88.74,
#   'low_price': 88.74,
#   'number_of_trades': 5,
#   'volume': 212,
#   'volume_weighted_average': 88.7392,
#   'time': datetime.datetime(2023, 1, 9, 21, 51, tzinfo=<UTC>)},
#  {'open_price': 88.7499,
#   'close_price': 88.7499,
#   'high_price': 88.7499,
#   'low_price': 88.7499,
#   'number_of_trades': 7,
#   'volume': 341,
#   'volume_weighted_average': 88.7445,
#   'time': datetime.datetime(2023, 1, 9, 21, 56, tzinfo=<UTC>)},
#  {'open_price': 88.72,
#   'close_price': 88.72,
#   'high_price': 88.72,
#   'low_price': 88.72,
#   'number_of_trades': 9,
#   'volume': 173,
#   'volume_weighted_average': 88.7223,
#   'time': datetime.datetime(2023, 1, 9, 21, 57, tzinfo=<UTC>)},
#  {'open_price': 88.72,
#   'close_price': 88.72,
#   'high_price': 88.72,
#   'low_price': 88.72,
#   'number_of_trades': 17,
#   'volume': 370,
#   'volume_weighted_average': 88.7114,
#   'time': datetime.datetime(2023, 1, 9, 22, 2, tzinfo=<UTC>)},
#  {'open_price': 88.7486,
#   'close_price': 88.7486,
#   'high_price': 88.7486,
#   'low_price': 88.7486,
#   'number_of_trades': 2,
#   'volume': 167,
#   'volume_weighted_average': 88.7484,
#   'time': datetime.datetime(2023, 1, 9, 22, 8, tzinfo=<UTC>)},
#  {'open_price': 88.75,
#   'close_price': 88.75,
#   'high_price': 88.75,
#   'low_price': 88.75,
#   'number_of_trades': 1,
#   'volume': 500,
#   'volume_weighted_average': 88.75,
#   'time': datetime.datetime(2023, 1, 9, 22, 12, tzinfo=<UTC>)},
#  {'open_price': 88.73,
#   'close_price': 88.73,
#   'high_price': 88.73,
#   'low_price': 88.73,
#   'number_of_trades': 3,
#   'volume': 502,
#   'volume_weighted_average': 88.7299,
#   'time': datetime.datetime(2023, 1, 9, 22, 14, tzinfo=<UTC>)},
#  {'open_price': 88.7299,
#   'close_price': 88.7283,
#   'high_price': 88.7299,
#   'low_price': 88.7283,
#   'number_of_trades': 4,
#   'volume': 796,
#   'volume_weighted_average': 88.7292,
#   'time': datetime.datetime(2023, 1, 9, 22, 22, tzinfo=<UTC>)},
#  {'open_price': 88.73,
#   'close_price': 88.73,
#   'high_price': 88.73,
#   'low_price': 88.73,
#   'number_of_trades': 8,
#   'volume': 428,
#   'volume_weighted_average': 88.7065,
#   'time': datetime.datetime(2023, 1, 9, 22, 23, tzinfo=<UTC>)},
#  {'open_price': 88.7,
#   'close_price': 88.7,
#   'high_price': 88.7,
#   'low_price': 88.7,
#   'number_of_trades': 1,
#   'volume': 300,
#   'volume_weighted_average': 88.7,
#   'time': datetime.datetime(2023, 1, 9, 22, 24, tzinfo=<UTC>)},
#  {'open_price': 88.73,
#   'close_price': 88.73,
#   'high_price': 88.73,
#   'low_price': 88.73,
#   'number_of_trades': 6,
#   'volume': 219,
#   'volume_weighted_average': 88.7225,
#   'time': datetime.datetime(2023, 1, 9, 22, 26, tzinfo=<UTC>)},
#  {'open_price': 88.75,
#   'close_price': 88.75,
#   'high_price': 88.75,
#   'low_price': 88.75,
#   'number_of_trades': 7,
#   'volume': 266,
#   'volume_weighted_average': 88.7315,
#   'time': datetime.datetime(2023, 1, 9, 22, 34, tzinfo=<UTC>)},
#  {'open_price': 88.72,
#   'close_price': 88.72,
#   'high_price': 88.72,
#   'low_price': 88.72,
#   'number_of_trades': 6,
#   'volume': 282,
#   'volume_weighted_average': 88.7162,
#   'time': datetime.datetime(2023, 1, 9, 22, 38, tzinfo=<UTC>)},
#  {'open_price': 88.7,
#   'close_price': 88.7,
#   'high_price': 88.7,
#   'low_price': 88.7,
#   'number_of_trades': 9,
#   'volume': 433,
#   'volume_weighted_average': 88.7005,
#   'time': datetime.datetime(2023, 1, 9, 22, 56, tzinfo=<UTC>)},
#  {'open_price': 88.6901,
#   'close_price': 88.69,
#   'high_price': 88.6901,
#   'low_price': 88.69,
#   'number_of_trades': 7,
#   'volume': 1608,
#   'volume_weighted_average': 88.6901,
#   'time': datetime.datetime(2023, 1, 9, 22, 57, tzinfo=<UTC>)},
#  {'open_price': 88.68,
#   'close_price': 88.68,
#   'high_price': 88.68,
#   'low_price': 88.68,
#   'number_of_trades': 1,
#   'volume': 100,
#   'volume_weighted_average': 88.68,
#   'time': datetime.datetime(2023, 1, 9, 23, 7, tzinfo=<UTC>)},
#  {'open_price': 88.68,
#   'close_price': 88.68,
#   'high_price': 88.68,
#   'low_price': 88.68,
#   'number_of_trades': 3,
#   'volume': 102,
#   'volume_weighted_average': 88.6801,
#   'time': datetime.datetime(2023, 1, 9, 23, 8, tzinfo=<UTC>)},
#  {'open_price': 88.6801,
#   'close_price': 88.67,
#   'high_price': 88.6801,
#   'low_price': 88.67,
#   'number_of_trades': 3,
#   'volume': 1100,
#   'volume_weighted_average': 88.6718,
#   'time': datetime.datetime(2023, 1, 9, 23, 10, tzinfo=<UTC>)},
#  {'open_price': 88.69,
#   'close_price': 88.69,
#   'high_price': 88.69,
#   'low_price': 88.69,
#   'number_of_trades': 4,
#   'volume': 532,
#   'volume_weighted_average': 88.69,
#   'time': datetime.datetime(2023, 1, 9, 23, 17, tzinfo=<UTC>)},
#  {'open_price': 88.67,
#   'close_price': 88.67,
#   'high_price': 88.67,
#   'low_price': 88.67,
#   'number_of_trades': 4,
#   'volume': 202,
#   'volume_weighted_average': 88.6723,
#   'time': datetime.datetime(2023, 1, 9, 23, 22, tzinfo=<UTC>)},
#  {'open_price': 88.69,
#   'close_price': 88.69,
#   'high_price': 88.69,
#   'low_price': 88.69,
#   'number_of_trades': 2,
#   'volume': 130,
#   'volume_weighted_average': 88.69,
#   'time': datetime.datetime(2023, 1, 9, 23, 28, tzinfo=<UTC>)},
#  {'open_price': 88.75,
#   'close_price': 88.75,
#   'high_price': 88.75,
#   'low_price': 88.75,
#   'number_of_trades': 13,
#   'volume': 410,
#   'volume_weighted_average': 88.7413,
#   'time': datetime.datetime(2023, 1, 9, 23, 38, tzinfo=<UTC>)},
#  {'open_price': 88.7,
#   'close_price': 88.7,
#   'high_price': 88.7,
#   'low_price': 88.7,
#   'number_of_trades': 2,
#   'volume': 101,
#   'volume_weighted_average': 88.6999,
#   'time': datetime.datetime(2023, 1, 9, 23, 47, tzinfo=<UTC>)},
#  {'open_price': 88.7,
#   'close_price': 88.7,
#   'high_price': 88.7,
#   'low_price': 88.7,
#   'number_of_trades': 1,
#   'volume': 150,
#   'volume_weighted_average': 88.7,
#   'time': datetime.datetime(2023, 1, 9, 23, 59, tzinfo=<UTC>)},
#  {'open_price': 88.69,
#   'close_price': 88.69,
#   'high_price': 88.69,
#   'low_price': 88.69,
#   'number_of_trades': 2,
#   'volume': 200,
#   'volume_weighted_average': 88.69,
#   'time': datetime.datetime(2023, 1, 10, 0, 1, tzinfo=<UTC>)},
#  {'open_price': 88.7,
#   'close_price': 88.7,
#   'high_price': 88.7,
#   'low_price': 88.7,
#   'number_of_trades': 2,
#   'volume': 120,
#   'volume_weighted_average': 88.6983,
#   'time': datetime.datetime(2023, 1, 10, 0, 5, tzinfo=<UTC>)},
#  {'open_price': 88.67,
#   'close_price': 88.67,
#   'high_price': 88.67,
#   'low_price': 88.67,
#   'number_of_trades': 24,
#   'volume': 882,
#   'volume_weighted_average': 88.671,
#   'time': datetime.datetime(2023, 1, 10, 0, 8, tzinfo=<UTC>)},
#  {'open_price': 88.65,
#   'close_price': 88.6,
#   'high_price': 88.65,
#   'low_price': 88.6,
#   'number_of_trades': 35,
#   'volume': 4256,
#   'volume_weighted_average': 88.6018,
#   'time': datetime.datetime(2023, 1, 10, 0, 16, tzinfo=<UTC>)},
#  {'open_price': 88.61,
#   'close_price': 88.6,
#   'high_price': 88.61,
#   'low_price': 88.6,
#   'number_of_trades': 6,
#   'volume': 608,
#   'volume_weighted_average': 88.6034,
#   'time': datetime.datetime(2023, 1, 10, 0, 17, tzinfo=<UTC>)},
#  {'open_price': 88.6,
#   'close_price': 88.6,
#   'high_price': 88.6,
#   'low_price': 88.6,
#   'number_of_trades': 6,
#   'volume': 1118,
#   'volume_weighted_average': 88.6003,
#   'time': datetime.datetime(2023, 1, 10, 0, 18, tzinfo=<UTC>)},
#  {'open_price': 88.5,
#   'close_price': 88.5,
#   'high_price': 88.5,
#   'low_price': 88.5,
#   'number_of_trades': 3,
#   'volume': 295,
#   'volume_weighted_average': 88.5016,
#   'time': datetime.datetime(2023, 1, 10, 0, 22, tzinfo=<UTC>)},
#  {'open_price': 88.55,
#   'close_price': 88.55,
#   'high_price': 88.55,
#   'low_price': 88.55,
#   'number_of_trades': 4,
#   'volume': 319,
#   'volume_weighted_average': 88.5413,
#   'time': datetime.datetime(2023, 1, 10, 0, 23, tzinfo=<UTC>)},
#  {'open_price': 88.5499,
#   'close_price': 88.5499,
#   'high_price': 88.5499,
#   'low_price': 88.5499,
#   'number_of_trades': 2,
#   'volume': 201,
#   'volume_weighted_average': 88.5498,
#   'time': datetime.datetime(2023, 1, 10, 0, 24, tzinfo=<UTC>)},
#  {'open_price': 88.5,
#   'close_price': 88.5,
#   'high_price': 88.5001,
#   'low_price': 88.5,
#   'number_of_trades': 21,
#   'volume': 900,
#   'volume_weighted_average': 88.5,
#   'time': datetime.datetime(2023, 1, 10, 0, 26, tzinfo=<UTC>)},
#  {'open_price': 88.6,
#   'close_price': 88.6,
#   'high_price': 88.6,
#   'low_price': 88.6,
#   'number_of_trades': 7,
#   'volume': 124,
#   'volume_weighted_average': 88.5769,
#   'time': datetime.datetime(2023, 1, 10, 0, 28, tzinfo=<UTC>)},
#  {'open_price': 88.55,
#   'close_price': 88.56,
#   'high_price': 88.56,
#   'low_price': 88.55,
#   'number_of_trades': 7,
#   'volume': 368,
#   'volume_weighted_average': 88.5639,
#   'time': datetime.datetime(2023, 1, 10, 0, 29, tzinfo=<UTC>)},
#  {'open_price': 88.5614,
#   'close_price': 88.5614,
#   'high_price': 88.5614,
#   'low_price': 88.5614,
#   'number_of_trades': 6,
#   'volume': 4140,
#   'volume_weighted_average': 88.5617,
#   'time': datetime.datetime(2023, 1, 10, 0, 34, tzinfo=<UTC>)},
#  {'open_price': 88.57,
#   'close_price': 88.57,
#   'high_price': 88.57,
#   'low_price': 88.57,
#   'number_of_trades': 3,
#   'volume': 180,
#   'volume_weighted_average': 88.5744,
#   'time': datetime.datetime(2023, 1, 10, 0, 36, tzinfo=<UTC>)},
#  {'open_price': 88.58,
#   'close_price': 88.58,
#   'high_price': 88.5801,
#   'low_price': 88.58,
#   'number_of_trades': 3,
#   'volume': 380,
#   'volume_weighted_average': 88.58,
#   'time': datetime.datetime(2023, 1, 10, 0, 39, tzinfo=<UTC>)},
#  {'open_price': 88.55,
#   'close_price': 88.5,
#   'high_price': 88.55,
#   'low_price': 88.5,
#   'number_of_trades': 9,
#   'volume': 376,
#   'volume_weighted_average': 88.5237,
#   'time': datetime.datetime(2023, 1, 10, 0, 52, tzinfo=<UTC>)},
#  {'open_price': 88.62,
#   'close_price': 88.62,
#   'high_price': 88.62,
#   'low_price': 88.62,
#   'number_of_trades': 3,
#   'volume': 351,
#   'volume_weighted_average': 88.62,
#   'time': datetime.datetime(2023, 1, 10, 0, 55, tzinfo=<UTC>)},
#  {'open_price': 88.6,
#   'close_price': 88.6,
#   'high_price': 88.6,
#   'low_price': 88.6,
#   'number_of_trades': 7,
#   'volume': 269,
#   'volume_weighted_average': 88.5814,
#   'time': datetime.datetime(2023, 1, 10, 0, 59, tzinfo=<UTC>)}]
